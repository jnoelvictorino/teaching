# %% [markdown]
# # **Method 1: Web Scraping**

# %% [markdown]
# Install necessary packages

# %%
# !pip install beautifulsoup4 requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (4.8.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2024.2.2)
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %% [markdown]
# Next, we import the packages into the notebook.
# 1. `pandas`: for managing data through dataframes (https://pandas.pydata.org/docs/)
# 2. `requests`: for connecting to webpages (needs an "agent" to emulate a web browser) (https://requests.readthedocs.io/en/latest/)
# 3. `beautifulsoup`: for processing HTML data collected from webpages (https://www.crummy.com/software/BeautifulSoup/)

# %%
# Import libraries
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random

# Declare headers for the requests agent
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 Edg/127.0.0.0',
  'Accept-Language': 'en-US,en;q=0.9',
  'Accept-Encoding': 'gzip, deflate, br',
  'Connection': 'keep-alive'
}

# %% [markdown]
# Let's try extracting the content of the article from Rappler:
#
# [Sara Duterte face book isang kaibigan](https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/)

# %%
# Define article based on the link
link = 'https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/'

# Request using `request` library
r = requests.get(link, headers=headers)
r
# Out:
# <Response [200]>

# %% [markdown]
# Look at the webpage's content

# %%
# Inspect the content
r.content
# Out:
# b'<!doctype html>\n<html lang="en-US" class="no-js">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<script>(function(c){c.add(\'has-js\');c.remove(\'no-js\')})(document.documentElement.classList)</script>\n\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<script>window.dataLayer = window.dataLayer || []; window.dataLayer.push( {"type":"post","subtype":"post","context":{"is_front_page":false,"is_singular":true,"is_archive":false,"is_home":false,"is_search":false,"is_404":false,"is_post_type_archive":false,"is_tax":false,"is_article":true},"user":{"role":[]},"blog":{"url":"https:\\/\\/www.rappler.com","id":1},"network":{"url":"https:\\/\\/www.rappler.com","id":1},"post":{"ID":2759297,"slug":"sara-duterte-face-book-isang-kaibigan","published":"2024-08-22 12:11:07","modified":"2024-08-22 12:11:24","comments":0,"template":"","thumbnail":"https:\\/\\/www.rappler.com\\/tachyon\\/2024\\/08\\/fc-ls-1.jpg","category":["Fact Check","National News","Newsbreak","Philippine News"],"movement":["factsfirstph"],"title":"FACT CHECK: VP Sara Duterte\'s face is in her book \'Isang Kaibigan\'","topics":["Fact checks on public officials","Duterte Fact Checks","Sara Duterte"],"primary_topic":"Fact checks on public officials","primary_category":"Fact Check","authors":["Rappler.com"],"author_ID":"4999","author_slug":"rappler-com"}} );</script>\n\t\t<!-- Google Tag Manager -->\n\t\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\t\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\t\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t\t})(window,document,\'script\',\'dataLayer\',\'GTM-WRN3RQG\');</script>\n\t\t<!-- End Google Tag Manager -->\n\t\t\n\t<!-- This site is optimized with the Yoast SEO Premium plugin v18.9 (Yoast SEO v19.14) - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>FACT CHECK: VP Sara Duterte&#039;s face is in her book &#039;Isang Kaibigan&#039;</title>\n\t<meta name="description" content="Numerous sources have shown pages of the book, one of which contains Duterte\xe2\x80\x99s picture along with some information about her" />\n\t<link rel="canonical" href="https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="FACT CHECK: VP Sara Duterte&#039;s face is in her book &#039;Isang Kaibigan&#039;" />\n\t<meta property="og:description" content="Numerous sources have shown pages of the book, one of which contains Duterte\xe2\x80\x99s picture along with some information about her" />\n\t<meta property="og:url" content="https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/" />\n\t<meta property="og:site_name" content="RAPPLER" />\n\t<meta property="article:published_time" content="2024-08-22T12:11:07+00:00" />\n\t<meta property="article:modified_time" content="2024-08-22T12:11:24+00:00" />\n\t<meta property="og:image" content="https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg" />\n\t<meta property="og:image:width" content="1280" />\n\t<meta property="og:image:height" content="720" />\n\t<meta property="og:image:type" content="image/jpeg" />\n\t<meta name="author" content="Lorenz Pasion" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:image" content="https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg" />\n\t<meta name="twitter:creator" content="@rapplerdotcom" />\n\t<meta name="twitter:site" content="@rapplerdotcom" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":["Article","ClaimReview"],"@id":"https://www.rappler.com/newsbreak/fact ...

# %% [markdown]
# Use `BeautifulSoup` to parse the webpage's HTML source code.

# %%
# Use BeautifulSoup to parse the HTML page
soup = BeautifulSoup(r.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script>(function(c){c.add('has-js');c.remove('no-js')})(document.documentElement.classList)</script>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <script>window.dataLayer = window.dataLayer || []; window.dataLayer.push( {"type":"post","subtype":"post","context":{"is_front_page":false,"is_singular":true,"is_archive":false,"is_home":false,"is_search":false,"is_404":false,"is_post_type_archive":false,"is_tax":false,"is_article":true},"user":{"role":[]},"blog":{"url":"https:\/\/www.rappler.com","id":1},"network":{"url":"https:\/\/www.rappler.com","id":1},"post":{"ID":2759297,"slug":"sara-duterte-face-book-isang-kaibigan","published":"2024-08-22 12:11:07","modified":"2024-08-22 12:11:24","comments":0,"template":"","thumbnail":"https:\/\/www.rappler.com\/tachyon\/2024\/08\/fc-ls-1.jpg","category":["Fact Check","National News","Newsbreak","Philippine News"],"movement":["factsfirstph"],"title":"FACT CHECK: VP Sara Duterte's face is in her book 'Isang Kaibigan'","topics":["Fact checks on public officials","Duterte Fact Checks","Sara Duterte"],"primary_topic":"Fact checks on public officials","primary_category":"Fact Check","authors":["Rappler.com"],"author_ID":"4999","author_slug":"rappler-com"}} );</script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-WRN3RQG');</script>
# <!-- End Google Tag Manager -->
# <!-- This site is optimized with the Yoast SEO Premium plugin v18.9 (Yoast SEO v19.14) - https://yoast.com/wordpress/plugins/seo/ -->
# <title>FACT CHECK: VP Sara Duterte's face is in her book 'Isang Kaibigan'</title>
# <meta content="Numerous sources have shown pages of the book, one of which contains Duterte’s picture along with some information about her" name="description">
# <link href="https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="FACT CHECK: VP Sara Duterte's face is in her book 'Isang Kaibigan'" property="og:title"/>
# <meta content="Numerous sources have shown pages of the book, one of which contains Duterte’s picture along with some information about her" property="og:description"/>
# <meta content="https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/" property="og:url"/>
# <meta content="RAPPLER" property="og:site_name"/>
# <meta content="2024-08-22T12:11:07+00:00" property="article:published_time"/>
# <meta content="2024-08-22T12:11:24+00:00" property="article:modified_time"/>
# <meta content="https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg" property="og:image"/>
# <meta content="1280" property="og:image:width"/>
# <meta content="720" property="og:image:height"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="Lorenz Pasion" name="author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg" name="twitter:image"/>
# <meta content="@rapplerdotcom" name="twitter:creator"/>
# <meta content="@rapplerdotcom" name="twitter:site"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":["Article","ClaimReview"],"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#article","isPartOf":{"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/"},"author":{"@id":"https://www.rappler.com/#/schema/person/6df94b691cab65f6e7ddef42b95b182b"},"headline":"FACT CHECK: VP Sara Duterte&#8217;s face is in her book &#8216;Isang Kaibigan&#8217;","datePublished":"2024-08-22T12:11:07+00:00","dateModified":"2024-08-22T12:11:24+00:00","mainEntityOfPage":{"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/"},"wordCount":561,"commentCount":0,"publisher":{"@id":"https://www.rappler.com/#organization"},"image":{"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#primaryimage"},"thumbnailUrl":"https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg","keywords":"Fact checks on public officials, Duterte Fact Checks, Sara Duterte, Fact Check, National News, Newsbreak, Philippine News","articleSection":"Fact checks on public officials, Duterte Fact Checks, Sara Duterte","inLanguage":"en-US","potentialAction":[{"@type":"CommentAction","name":"Comment","target":["https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#respond"]}],"itemReviewed":{"@type":"CreativeWork","datePublished":"2024-08-22T12:11:07+00:00","dateModified":"2024-08-22T12:11:24+00:00","author":{"@type":"Person","name":" ᎥⓃᗪ𝒶𝕪 𝐌𝔦Ⓢ𝓼 𝓜"}},"claimReviewed":"The face of Vice President Sara Duterte is not in the children’s book that she wrote titled Isang Kaibigan.","reviewRating":{"@type":"Rating","alternateName":"False"},"url":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/","locationCreated":"Philippines","hasPart":[],"copyrightYear":"2024","copyrightHolder":{"@id":"https://www.rappler.com/#organization"}},{"@type":"WebPage","@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/","url":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/","name":"FACT CHECK: VP Sara Duterte's face is in her book 'Isang Kaibigan'","isPartOf":{"@id":"https://www.rappler.com/#website"},"primaryImageOfPage":{"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#primaryimage"},"image":{"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#primaryimage"},"thumbnailUrl":"https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg","datePublished":"2024-08-22T12:11:07+00:00","dateModified":"2024-08-22T12:11:24+00:00","description":"Numerous sources have shown pages of the book, one of which contains Duterte’s picture along with some information about her","breadcrumb":{"@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/"]}]},{"@type":"ImageObject","inLanguage":"en-US","@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#primaryimage","url":"https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg","contentUrl":"https://www.rappler.com/tachyon/2024/08/fc-ls-1.jpg","width":1280,"height":720,"caption":"File, Person, Computer"},{"@type":"BreadcrumbList","@id":"https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Latest News","item":"https://www.rappler.com/latest/"},{"@type":"ListItem","position":2,"name":"FACT CHECK: VP Sara Duterte&#8217;s face is in her book &#8216;Isang Kaibigan&#8217;"}]},{"@type":"WebSite","@id":"https://www.rappler.com/#website","url":"https://www.rappler.com/","name":"RAPPLER","description": ...
# <!-- / Yoast SEO Premium plugin. -->
# <link href="//cdn.cxense.com" rel="dns-prefetch"/>
# <link href="//www.rappler.com" rel="dns-prefetch"/>
# <link href="//experience-ap.piano.io" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//srvr.dmvs-apac.com" rel="dns-prefetch"/>
# <link href="//rappler.altis.cloud" rel="dns-prefetch"/>
# <link href="https://www.rappler.com/feed/" rel="alternate" title="RAPPLER » Feed" type="application/rss+xml"/>
# <link href="https://www.rappler.com/comments/feed/" rel="alternate" title="RAPPLER » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/feed/" rel="alternate" title="RAPPLER » FACT CHECK: VP Sara Duterte’s face is in her book ‘Isang Kaibigan’ Comments Feed" type="application/rss+xml"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/1cdec6e278f2e85e40f08af1112576f3.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/6bbaad76a4547e68e0111da3ce1c929f.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/8a64d0d4cd2b8d0ee70b9f60ecfbe8f8.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/f55a0177f65edc649d6e45ba6a5a173f.woff2" rel="preload" type="font/woff2"/>
# <link as="style" href="https://www.rappler.com/wp-includes/css/dist/block-library/style.min.css?ver=6.3.2" rel="preload"/>
# <link as="style" href="https://www.rappler.com/content/themes/rappler/build/rappler-theme-style.0ec3c78fa570a9b4b5d2.css" rel="preload"/>
# <link as="style" href="https://www.rappler.com/content/mu-plugins/rappler-blocks/build/rappler-blocks-frontend.d2edfed216c0e3671c75.css" rel="preload"/>
# <link href="https://www.rappler.com/wp-includes/css/dist/block-library/style.min.css?ver=6.3.2" id="wp-block-library-css" media="all" rel="stylesheet"/>
# <style id="classic-theme-styles-inline-css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <style id="global-styles-inline-css">
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--navy: #172038;--wp--preset--color--orange-courage: #f04f3c;--wp--preset--color--ghost-white: #f5f6ff;--wp--preset--color--mint: #c7e4da;--wp--preset--color--vanilla: #fff;--wp--preset--color--move: #50558b;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flow > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-flow > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-flow > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignleft{float: left;margin-inline-start: 0;margin-inline-end: 2em;}body .is-layout-constrained > .alignright{float: right;margin-inline-start: 2em;margin-inline-end: 0;}body .is-layout-constrained > .aligncenter{margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > :where(:not(.alignleft):not(.alignright):not(.alignfull)){max-width: var(--wp--style--global--content-size);margin-left: auto !important;margin-right: auto !important;}body .is-layout-constrained > .alignwide{max-width: var(--wp--style--global--wide-size);}body .is-layout-flex{display: flex;}body .is-la ...
# .wp-block-navigation a:where(:not(.wp-element-button)){color: inherit;}
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# .wp-block-pullquote{font-size: 1.5em;line-height: 1.6;}
# </style>
# <style id="rappler-theme-style-load-inline-css">
# /*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */html{line-height:1.15;-webkit-text-size-adjust:100%}body{margin:0}main{display:block}h1{font-size:2em;margin:.67em 0}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace,monospace;font-size:1em}a{background-color:transparent}abbr[title]{border-bottom:none;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}img{border-style:none}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:.35em .75em .625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details{display:block}summary{display:list-item}[hidden],template{display:none}:root{--white:#fff;--black:#000;--navy:#172038;--navy-dark:#121a2d;--navy-light:#454d60;--orange-courage:#ff5f1b;--orange-courage-light:#ff8c5a;--ghost-white:#f5f6ff;--ash:#ebedff;--blueblack:#18213a;--hustle:#1e1558;--midblue:#575d75;--midnight:#101626;--midnight-light:#404551;--midnight-lighter:#70737d;--mint:#c7e4da;--move:#50558b;--move-dark:#404464;--move-light:#7377a2;--system-gray:#6c6f8b;--system-gray-dark:#56596f;--system-gray-darker:#414353;--vanilla:#fff;--vanilla-dark:#eeeef3;--vanilla-darker:#cbccdc;--wave:#261c6c;--nerve:#6c6f8b;--afraid:#f9e950;--afraid-dark:#496667;--afraid-light:#6b8788;--amused:#79cbf9;--amused-dark:#2de133;--amused-light:#71ff75;--angry:#f8505e;--angry-dark:#df1f1f;--angry-light:#ff4949;--annoyed:#935bb8;--annoyed-dark:#8142ab;--annoyed-light:#af6eda;--dont-care:#bab9b9;--dont-care-dark:#b0b0b0;--dont-care-light:#cccbcb;--happy:#fecc32;--happy-dark:#f0ba12;--happy-light:#ffd862;--inspired:#ff6f31;--inspired-dark:#ff5f1b;--inspired-light:#ff8551;--sad:#669cd0;--sad-dark:#528fca;--sad-light:#6da8df;--nerve-angry:#fa2c2c;--events-black:#151515;--events-bluepurple:#50558b;--events-error:#fabebe;--events-gold:#e4b130;--events-maroon:#510d69;--events-lightgrey:#caccd8;--default-background-color:var(--ghost-white);--default-background-color-alt:var(--navy);--default-text-color:var(--navy);--default-text-color-alt:var(--white);--default-border-color:var(--navy);--default-border-color-alt:var(--white);--default-cta-color:var(--navy);--heading-one-color:var(--navy);--heading-two-color:var(--navy);--heading-three-color:var(--navy);--heading-four-color:var(--navy);--heading-five-color:var(--navy);--heading-six-color:var(--navy)}.has-navy-background-color{background-color:#172038;background-color:var(--navy)}.has-navy-color{color:#172038;color:var(--navy)}.has-orange-courage-background-color{background-color:#ff5f1b;background-color:var(--orange-courage)}.has-orange-courage-color{color:#ff5f1b;color:var(--orange-courage)}.has-ghost-white-background-color{background-color:#f5f6ff;background-color:var(--ghost-white)}.has-ghost-white-color{color:#f5f6ff;color:var(--ghost-white)}.has-midnight-backgrou ...
# </style>
# <link href="https://www.rappler.com/content/themes/rappler/build/rappler-theme-style.0ec3c78fa570a9b4b5d2.css?ver=0ec3c78fa570a9b4b5d2" id="rappler-theme-style-css" integrity="sha384-Ut5EvLitqa5cTxfM4/kgO+62U5NzvTTOvTPFVzyN4pcOBlEKbri//jBK1nB+2LZc" media="all" rel="stylesheet"/>
# <link href="https://www.rappler.com/content/mu-plugins/rappler-blocks/build/rappler-blocks-frontend.d2edfed216c0e3671c75.css?ver=d2edfed216c0e3671c75" id="rappler-blocks-frontend-css" integrity="sha384-CrIrt2L9ln9OP+yKI3z0cCdz9X/YdkZskl1koc+qIa/PWz2Uo71DqObk0EP4azuO" media="all" rel="stylesheet"/>
# <script id="lazy-load-scripts-footer-before">rapplerCxense = {"load_inline_from_composer":"yes","widget_inline_article_id":"2babd9be39f41eff3abcbdc513a4d3d4bbca8a33","element_inline_article_id":"cx_inline","widget_after_article_id":"8ae670c83901191ea83ddc6768902cc0fe07315f","element_after_article_id":"cx_after-article","use_soft_section_after_article":false,"soft_section_widget_id":"1aca31944a2782773a98fa3c056877dad633f8aa","widget_related_topics_id":"a0da9e337862e0626476a632f993ba817f7b06fb","element_related_topics_id":"cx_related-topics-widget"};window.tp = window.tp || [];rapplerPianoId = {"elements":{".masthead":"masthead--logged-in",".burger-nav":"burger-nav--logged-in"},"logout_button":"","piano_id_form":"piano-id-form-overlay","rappler_plus_offer_id":"OFIZWP6GZ6I9","rappler_plus_template_id":"OTOVFQ3UAN4R","subscriber_rid":"R2Q6QPY"};var rapplerSpeechify = {"content_selector":"article.single-article.post","element_id":"rappler-speechify","ignored_el_classes":["rappler-speechify","author-block","comments","dailymotion-container","piano-article__plea","piano-article__prearticle","post-single__category","post-single__ai-summary-section-container","post-single__image","post-single__moodmeter","post-single__end-article-moodmeter","post-single__related-topics-widget","post-single__share","post-single__taboola","rappler-ad-container","recommended-articles","related-article","related-topics","video-embed-container"],"primary_color":"#f04f3c"};rapplerComments = {"comments_count":0,"endpoint":"https:\/\/www.rappler.com\/wp-json\/wp\/v2\/comments","form_id":"rappler-comments-form","intro":{"is_logged_in":{"has_comments":{"header":"Join the conversation!","subheader":"Become a Rappler+ member and participate in the discussion.\n Why is it important for you to register? <a href='https:\/\/www.rappler.com\/plus-membership-program\/frequently-asked-questions\/'>Know here<\/a>.","cta_1":"JOIN RAPPLER+ TO COMMENT","cta_2":""},"no_comments":{"header":"Join the conversation!","subheader":"Become a Rappler+ member and participate in the discussion.\n Why is it important for you to register? <a href='https:\/\/www.rappler.com\/plus-membership-program\/frequently-asked-questions\/'>Know here<\/a>.","cta_1":"JOIN RAPPLER+ TO COMMENT","cta_2":""}},"is_not_logged_in":{"has_comments":{"header":"Join the conversation!","subheader":"Be a part of our global community of Rappler+ members and discuss stories while getting access to exclusive content and events. Your subscription helps support press freedom. <a href=\"https:\/\/www.rappler.com\/plus-membership-program\/frequently-asked-questions\/\">Learn more<\/a>.","cta_1":"JOIN RAPPLER+ TO COMMENT","cta_2":"Already a member?"},"no_comments":{"header":"Start the conversation!","subheader":"Be a part of our global community of Rappler+ members and discuss stories while getting access to exclusive content and events. Your subscription helps support press freedom. <a href=\"https:\/\/www.rappler.com\/plus-membership-program\/frequently-asked-questions\/\">Learn more<\/a>.","cta_1":"JOIN RAPPLER+ TO COMMENT","cta_2":"Already a member?"}}},"is_open":true,"list_endpoint":"https:\/\/www.rappler.com\/wp-json\/rappler\/v1\/comments","list_id":"rappler-comment-list","order":"","order_by":"","page_number":1,"post_id":2759297,"read_more_threshold":125,"see_more_replies_threshold":2,"share_button_class":"comment-share--button","signup_section_id":"rappler-comments-signup-intro","sort_form_id":"comment-sort-form","wrapper_id":"rappler-comments","strings":{"form_placeholder":"Commenting as %name%\u2026","read_less":"Read less","read_more":"Read more","see_more_replies":"See more replies","share_tooltip_text":"URL copied.","signin":"Sign in."}};</script><script async="" id="cxense-script-js" src="https://cdn.cxense.com/cx.cce.js?ver=6.3.2"></script>
# <script async="" id="rappler-gpt-js" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script id="rappler-gpt-js-after">
# window.rapplerAds = {"availableSlots":{"top-billboard":{"path":"R6_Desktop\/Article\/R6_Top_Billboard","sizes":[[970,90],[728,90]],"device":"desktop","collapseEmptyDiv":false},"middle-1":{"path":"R6_Desktop\/Article\/R6_Middle_1","mobile":"R6_Mobile\/Article\/R6_Middle_1","sizes":[[300,250],[336,280]],"device":"desktop"},"middle-2":{"path":"R6_Desktop\/Article\/R6_Middle_2","sizes":[[300,250],[336,280]],"device":"desktop"},"middle-3":{"path":"R6_Desktop\/Article\/R6_Middle_3","sizes":[[300,250],[336,280]],"device":"desktop"},"sticky-leaderboard":{"path":"R6_Desktop\/Article\/R6_Sticky_Leaderboard","sizes":[[970,90],[728,90]],"device":"desktop"},"bottom-leaderboard":{"path":"R6_Desktop\/Article\/R6_Bottom_Leaderboard","sizes":[[728,90]],"device":"desktop"},"oop":{"path":"R6_Desktop\/Article\/OOP","sizes":[[1,1]],"device":"desktop","isOop":true},"mobile-top-billboard":{"path":"R6_Mobile\/Article\/R6_Top_Billboard","sizes":[[320,100],[300,100],[320,50],[300,50]],"device":"mobile","collapseEmptyDiv":false,"minHeight":70},"mobile-middle-1":{"path":"R6_Mobile\/Article\/R6_Middle_1","sizes":[[300,250],[336,280]],"device":"mobile","collapseEmptyDiv":false},"mobile-middle-2":{"path":"R6_Mobile\/Article\/R6_Middle_2","sizes":[[300,250],[336,280]],"device":"mobile"},"mobile-middle-3":{"path":"R6_Mobile\/Article\/R6_Middle_3","sizes":[[300,250],[336,280]],"device":"mobile"},"mobile-sticky-leaderboard":{"path":"R6_Mobile\/Topic\/R6_Sticky_Leaderboard","sizes":[[320,50]],"device":"mobile"},"mobile-bottom-leaderboard":{"path":"R6_Mobile\/Article\/R6_Bottom_Leaderboard","sizes":[[320,50]],"device":"mobile"},"mobile-oop":{"path":"R6_Mobile\/Article\/R6_OOP","sizes":[[1,1]],"device":"mobile","isOop":true}},"targeting":{"page_type":"Article","articleID":["2759297"],"Topic":["duterte-fact-checks","fact-checks-on-public-officials","sara-duterte"],"Section":["newsbreak"],"Subsection":["fact-check"]},"adpushupEnabled":true,"networkCode":"15125093","persistedQueryId":"82ef547962d8ecd598da83a1543cb91a6670175e","definedSlots":[],"queue":[],"breakpoints":{"desktop":[1024,100],"tablet":[768,100]},"initialized":false,"ads_free_mode":false,"disabled":false};
# 	window.rapplerAds.displayAd = function ( id, divId ) {
# 		window.cX = window.cX || {};
# 		window.cX.callQueue = window.cX.callQueue || [];
# 		window.googletag = window.googletag || { cmd: [] };
# 		window.rapplerAds = window.rapplerAds || {};
# 		/**
# 		 * Callback to display Ads.
# 		 */
# 		function callback() {
# 			window.cX.callQueue.push( [
# 				'invoke',
# 				function () {
# 					const currSlot = window.rapplerAds.availableSlots[id];
# 					// define slot if ad is dynamic
# 					if ( currSlot.insertedDynamically ) {
# 						window.googletag.cmd.push( () => {
# 							window.rapplerAds.defineAdSlot( id, true );
# 						} );
# 					}
#
# 					// define slot if ad is reusable
# 					if ( currSlot.isReusable && divId ) {
# 						window.googletag.cmd.push( () => {
# 							window.rapplerAds.defineAdSlot( id, false, divId );
# 						} );
# 					}
#
# 					window.googletag.cmd.push( () => {
# 						if (!divId) divId = 'gpt-' + id;
# 						window.googletag.display( divId );
# 					} );
# 				},
# 			] );
# 		}
#
# 		if ( window.rapplerAds.initialized ) {
# 			callback();
# 		} else {
# 			window.rapplerAds.queue.push( callback );
# 		}
# 	};
# </script>
# <script async="" id="rappler-gpt-init-js" integrity="sha384-e9uEdoKis3wNbPFQyV9CRagUNurN1rBAnF5ZQf8V3F5ggUQHVZc6bci7jvc2OwzH" src="https://www.rappler.com/content/mu-plugins/rappler-ads/assets/build/rappler-gpt-init.7b8658d6bbb723b6ac9b.js?ver=7b8658d6bbb723b6ac9b"></script>
# <meta content="FACT CHECK: VP Sara Duterte’s face is in her book ‘Isang Kaibigan’" name="cXenseParse:title"/><meta content="post" name="cXenseParse:pageclass"/><meta content="post" name="section"/><meta content="post" name="cXenseParse:rap-articletype"/><meta content="2024-08-22T20:11:07Z" name="cXenseParse:publishtime"/><meta content="2024-08-22T20:11:07Z" name="cXenseParse:recs:publishtime"/><meta content="2759297" name="cXenseParse:articleid"/><meta content="Rappler.com" name="cXenseParse:author"/><meta content="Duterte Fact Checks, Fact checks on public officials, Sara Duterte" data-separator="," name="cXenseParse:keywords"/><meta content="Duterte Fact Checks, Fact checks on public officials, Sara Duterte" data-separator="," name="cXenseParse:rap-keywords"/><meta content="Duterte Fact Checks, Fact checks on public officials, Sara Duterte" data-separator="," name="cXenseParse:rap-topics"/><meta content="RAPPLER" name="cXenseParse:sitename"/><meta content="true" name="cXenseParse:mainsite"/><meta content="Fact checks on public officials" name="cXenseParse:primarytopic"/><meta content="Fact checks on public officials" name="cXenseParse:rap-primaryTopic"/><meta content="https://www.rappler.com/topic/fact-checks-on-public-officials/" name="cXenseParse:rap-primaryTopicUrl"/><meta content="Fact Check" name="cXenseParse:primarysection"/><meta content="Fact Check" name="cXenseParse:rap-primarySection"/><meta content="https://www.rappler.com/newsbreak/fact-check/" name="cXenseParse:rap-primarySectionUrl"/>
# <meta content="Duterte Fact Checks" property="article:tag"/>
# <meta content="Fact checks on public officials" property="article:tag"/>
# <meta content="Sara Duterte" property="article:tag"/>
# <link href="https://www.rappler.com/wp-json/" rel="https://api.w.org/"/><link href="https://www.rappler.com/wp-json/wp/v2/posts/2759297" rel="alternate" type="application/json"/><link href="https://www.rappler.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="Altis (WordPress 6.3.2)" name="generator"/>
# <link href="https://www.rappler.com/?p=2759297" rel="shortlink"/>
# <link href="https://www.rappler.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.rappler.com%2Fnewsbreak%2Ffact-check%2Fsara-duterte-face-book-isang-kaibigan%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.rappler.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.rappler.com%2Fnewsbreak%2Ffact-check%2Fsara-duterte-face-book-isang-kaibigan%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <!-- Stream WordPress user activity plugin v3.10.0 -->
# <script type="text/javascript">
# 		"use strict";!function(){for(var t,e;!(t=window.document.getElementsByTagName("head")[0]);)window.document.getElementsByTagName("html")[0].appendChild(window.document.createElement("head"));"function"!=typeof window.document.querySelectorAll&&((e=window.document.createElement("script")).type="text/javascript",e.charset="utf-8",e.setAttribute("crossorigin","anonymous"),e.async=!0,e.src=(window.document.location.protocol||"http:")+"//api.deep.bi/v3/sizzle.js",t.appendChild(e)),(e=window.document.createElement("script")).type="text/javascript",e.charset="utf-8",e.setAttribute("crossorigin","anonymous"),e.async=!0,e.src=(window.document.location.protocol||"http:")+"//api.deep.bi/v3/init.js",t.appendChild(e)}();
# 	</script>
# <script type="text/javascript">
# 		r(function () {
# 			window.deep = window.deepTracker.track("TR8x0HLI2e7B", "soI2uyBN7c7KXjgBwLE2s2oY");
# 			window.deep.options.media = true;
# 			window.deep.options.dntignore = true;
#
# 			window.deep.options.dataCollector = true;
# 			window.deep.options.globalVariablesDataCollector = true;
# 			window.deep.options.scrolldepth = true;
# 			window.deep();
# 		});
# 		function r(f) {
# 			if (!window.deepTracker || !window.deepTracker.isInitialized()) {
# 				setTimeout('r(' + f + ')', 9);
# 			} else {
# 				f();
# 			}
# 		}
# 	</script>
# <link href="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png?fit=32%2C32" rel="icon" sizes="32x32"/>
# <link href="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png" rel="icon" sizes="192x192"/>
# <link href="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png" rel="apple-touch-icon"/>
# <meta content="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png" name="msapplication-TileImage"/>
# </meta></meta></head>
# <body class="post-template-default single single-post postid-2759297 single-format-standard wp-custom-logo wp-embed-responsive">
# <script>window.dataLayer = window.dataLayer || []; window.dataLayer.push( {"type":"post","subtype":"post","context":{"is_front_page":false,"is_singular":true,"is_archive":false,"is_home":false,"is_search":false,"is_404":false,"is_post_type_archive":false,"is_tax":false,"is_article":true},"user":{"role":[]},"blog":{"url":"https:\/\/www.rappler.com","id":1},"network":{"url":"https:\/\/www.rappler.com","id":1},"post":{"ID":2759297,"slug":"sara-duterte-face-book-isang-kaibigan","published":"2024-08-22 12:11:07","modified":"2024-08-22 12:11:24","comments":0,"template":"","thumbnail":"https:\/\/www.rappler.com\/tachyon\/2024\/08\/fc-ls-1.jpg","category":["Fact Check","National News","Newsbreak","Philippine News"],"movement":["factsfirstph"],"title":"FACT CHECK: VP Sara Duterte's face is in her book 'Isang Kaibigan'","topics":["Fact checks on public officials","Duterte Fact Checks","Sara Duterte"],"primary_topic":"Fact checks on public officials","primary_category":"Fact Check","authors":["Rappler.com"],"author_ID":"4999","author_slug":"rappler-com"}} );</script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-WRN3RQG');</script>
# <!-- End Google Tag Manager -->
# <header class="site-header">
# <div class="masthead masthead-upper">
# <div class="masthead__nav">
# <button aria-expanded="false" class="masthead__nav--burger-button" id="burger-nav__toggle">
# <span class="masthead__nav--burger">
# <span class="masthead__nav--burger-icon"></span>
# <span class="masthead__nav--burger-icon"></span>
# </span>
# <span class="screen-reader-text">Open navigation</span>
# </button>
# <a class="masthead__breadcrumbs--taxonomy-label" href="https://www.rappler.com/newsbreak/fact-check/">Fact Check</a><div aria-hidden="true" aria-labelledby="burger-nav__toggle" class="burger-nav-overlay burger-nav-overlay--no-transition" id="burger-nav-overlay">
# <nav class="burger-nav" id="burger-navigation">
# <div class="burger-nav__top-bar" id="burger-nav__top-bar">
# <div class="burger-nav__top-bar-left">
# <div class="burger-nav__logo" id="burger-nav__logo">
# <a class="logo" href="#">
# <span class="screen-reader-text">
# 							RAPPLER						</span>
# <svg fill="none" height="41" viewbox="0 0 48 41" width="48" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M20.6008 39.6121C14.7202 38.2578 10.3871 34.9926 7.3622 30.7105C5.63816 28.2705 4.28467 25.3317 3.74304 21.6822C3.16392 17.7819 3.86575 13.8049 5.0131 10.8168C3.4027 13.8755 2.33273 17.2387 2.63196 21.4923C2.77039 23.4683 3.23042 25.2592 3.77508 26.8772C4.32336 28.5067 4.97985 29.9786 5.83885 31.3755C8.91638 36.3774 14.2481 39.4995 21.776 39.9915C22.2977 40.0256 22.9741 40.1383 23.3634 40.0548C23.3326 40.0621 22.8556 39.986 22.6332 39.9604C21.9005 39.8758 21.2223 39.7546 20.6008 39.6121ZM6.69544 27.2572C8.66793 31.5886 12.3705 34.5286 16.5053 36.4754C14.3871 28.5993 12.2672 20.7262 10.1556 12.844C9.16484 12.5547 8.2605 12.1796 7.26669 11.8934C6.02685 13.7026 5.19929 16.4282 5.1074 19.3378C5.01552 22.2747 5.70707 25.0881 6.69544 27.2572ZM25.1086 21.175C26.5141 20.4984 28.1565 19.2373 28.1565 17.2473C28.1565 16.0355 27.5726 14.8511 26.95 14.1429C26.2578 13.3555 25.1316 12.8434 23.7751 12.9073C21.4139 13.0187 19.3943 14.0095 17.235 14.4595C18.0353 17.1456 18.7819 19.8858 19.5526 22.6005C20.5168 22.4154 21.4877 22.1438 22.3781 21.9356C23.3399 21.7103 24.2466 21.5903 25.1086 21.175ZM40.1251 30.3939C41.8764 27.2602 43.1634 23.4786 42.9512 18.7995C42.7511 14.4029 40.9654 10.9337 39.014 8.25067C37.0168 5.50431 34.4307 3.19518 31.0769 1.69351C27.8736 0.258827 22.9723 -0.468867 18.6954 0.584614C27.8942 -0.116286 34.1188 3.54532 37.6811 8.85231C39.4608 11.5043 41.0808 14.672 41.6811 18.5772C42.3485 22.9208 41.4599 27.2949 39.8712 30.0766C39.3181 29.5091 38.6943 29.0122 38.2209 28.3661C40.4824 25.0369 40.6486 18.4591 39.2371 14.1106C37.883 9.93867 34.8484 6.80198 31.3634 4.79793C29.585 3.77489 27.3719 2.95464 24.9188 2.64347C22.2953 2.31098 19.5327 2.56187 17.2996 3.30905C13.3843 4.61768 10.34 7.27818 8.15652 10.3095C8.00298 10.5233 7.78173 10.7181 7.80712 10.9112C11.3568 9.97886 14.9421 9.02099 18.5377 8.06007C20.3125 7.58569 22.1067 6.97005 24.1571 6.88784C28.5561 6.71064 31.4698 8.63857 33.1099 11.4495C33.9519 12.8921 34.6332 14.6038 34.6973 16.6444C34.768 18.8987 34.1085 20.5307 33.2054 21.935C32.3161 23.3154 31.1821 24.417 29.776 25.2927C34.2965 28.9099 39.0388 32.4472 43.5871 35.9998C43.7201 36.104 43.896 36.1831 43.968 36.3482C36.3657 33.6487 28.6595 30.8847 21.0778 28.2698C22.0196 31.2902 22.7952 34.4762 23.7763 37.4564C27.1494 37.5478 29.4865 36.3329 31.6814 35.1443C37.1014 36.3676 42.5443 37.5679 48 38.7559C45.5209 36.0644 42.6767 33.1621 40.1251 30.3939ZM1.48884 17.9445C1.97788 12.4007 4.15894 8.06676 6.6634 4.70293C5.08504 6.31238 3.5103 8.12827 2.31399 10.2779C1.13521 12.397 0.187343 14.9534 0.0283587 17.9439C-0.146343 21.2194 0.506522 24.006 1.42537 26.4333C2.33636 28.8398 3.57015 30.9882 5.0131 32.7371C2.87255 28.8642 0.944183 24.1132 1.48884 17.9445ZM42.3158 29.6656C44.5265 26.4868 46.4089 21.5227 45.1733 16.2023C44.1215 11.6723 41.446 8.24579 38.5697 5.71683C40.9998 8.43579 43.1126 11.8569 43.9674 16.234C44.8977 20.9978 43.9256 26.2682 42.3158 29.6656Z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# <button class="burger-nav__top-bar-button burger-nav__top-bar-button--back" id="burger-nav__back" type="button">
# <svg class="burger-nav__top-bar-back-button" viewbox="0 0 31 31">
# <g fill="#F04F3C" fill-rule="evenodd" id="Navigation" stroke="none" stroke-width="1">
# <g id="M/Sections/L1" transform="translate(-32.000000, -20.000000)">
# <g fill="inherit" id="UI/Arrow/Orange" transform="translate(32.000000, 20.000000)">
# <path d="M3.18350997,14.6880517 L30.3717613,14.6880517 L30.3717613,16.3722623 L3.27044743,16.3722623 L16.744404,29.8684666 L15.5525053,31.0584005 L6.1284311e-13,15.4802153 L15.5544218,-4.79616347e-14 L16.7424875,1.19376085 L3.18350997,14.6880517 Z" id="Combined-Shape"></path>
# </g>
# </g>
# </g>
# </svg>
# </button>
# </div>
# <div class="burger-nav__top-bar-right">
# <button class="burger-nav__top-bar-button" id="burger-menu-close" type="button">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M23.3409 2.94343L21.0567 0.65918L12.0007 9.71519L2.94465 0.65918L0.6604 2.94343L9.71641 11.9994L0.6604 21.0554L2.94465 23.3397L12.0007 14.2837L21.0567 23.3397L23.3409 21.0554L14.2849 11.9994L23.3409 2.94343Z" fill="white"></path>
# </svg>
# <span class="screen-reader-text">
# 						Close menu					</span>
# </button>
# </div>
# </div>
# <div class="burger-nav__panel burger-nav__main-panel burger-nav__main-panel--show burger-nav__panel-depth-0" data-depth="0" id="burger-nav__main-panel"><div class="burger-nav__scrollable"><ul class="menu" id="menu-primary-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1503287" id="menu-item-1503287"><a href="https://www.rappler.com/latest/">Latest news</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512002" id="menu-item-1512002"><a href="https://www.rappler.com/philippines/weather/">Weather</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511924" id="menu-item-1511924"><a href="https://www.rappler.com/video/">Video</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511913" id="menu-item-1511913"><a href="https://www.rappler.com/brandrap/">BrandRap</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1503293" id="menu-item-1503293"><a href="https://www.rappler.com/nation/">Philippines</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511921" id="menu-item-1511921"><a href="https://www.rappler.com/newsbreak/">Newsbreak</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511928" id="menu-item-1511928"><a href="https://www.rappler.com/plus-membership-program/">Rappler+ Exclusives</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1512063" id="menu-item-1512063"><a href="https://www.rappler.com/topic/special-coverages/">Special coverages</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511927" id="menu-item-1511927"><a href="https://www.rappler.com/sports/">Sports</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511926" id="menu-item-1511926"><a href="https://www.rappler.com/world/">World</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511925" id="menu-item-1511925"><a href="https://www.rappler.com/voices/">Voices</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511916" id="menu-item-1511916"><a href="https://www.rappler.com/entertainment/">Entertainment</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511915" id="menu-item-1511915"><a href="https://www.rappler.com/business/">Business</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511919" id="menu-item-1511919"><a href="https://www.rappler.com/life-and-style/">Life and Style</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511923" id="menu-item-1511923"><a href="https://www.rappler.com/technology/">Technology</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511920" id="menu-item-1511920"><a href="https://www.rappler.com/moveph/">MovePH</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511922" id="menu-item-1511922"><a href="https://www.rappler.com/science/">Science</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511917" id="menu-item-1511917"><a href="https://www.rappler.com/environment/">Environment</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-2422314" id="menu-item-2422314"><a href="https://www.rappler.com/bulletin-board/">Bulletin Board</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2641787" id="menu-item-2641787"><a href="https://communities.rappler.com/ytUTSmRbUiTCeeZEWA?mode=download-app">Communities</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-has-children menu-item-2133993" id="menu-item-2133993"><a href="https://www.rappler.com">Movements</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-1512062" id="menu-item-1512062"><a href="https://www.rappler.com/topics">Topics</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-has-children menu-item-1511912" id="menu-item-1511912"><a href="https://www.rappler.com/about/">About Rappler</a></li>
# </ul></div></div><div class="burger-nav__panel burger-nav__sub-panel burger-nav__panel-depth-1" data-depth="1" id="submenu-panel-1511924">
# <div class="burger-nav__scrollable">
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1513260" id="menu-item-1513260"><a href="https://www.rappler.com/video/">SEE ALL VIDEOS</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512039" id="menu-item-1512039"><a href="https://www.rappler.com/video/hold-the-line-maria-ressa-interview/">Hold The Line</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512036" id="menu-item-1512036"><a href="https://www.rappler.com/video/editorial/">Video editorial</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512040" id="menu-item-1512040"><a href="https://www.rappler.com/video/act-one/">Act One</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512041" id="menu-item-1512041"><a href="https://www.rappler.com/video/basagan-ng-trip/">Basagan ng Trip</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512042" id="menu-item-1512042"><a href="https://www.rappler.com/video/daily-wrap/">Daily wRap</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512043" id="menu-item-1512043"><a href="https://www.rappler.com/video/documentaries/">Documentaries</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512044" id="menu-item-1512044"><a href="https://www.rappler.com/video/duterte-live/">Duterte LIVE</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512045" id="menu-item-1512045"><a href="https://www.rappler.com/video/rappler-live-jam/">Live Jam videos</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512034" id="menu-item-1512034"><a href="https://www.rappler.com/video/rappler-talk-video/">Rappler Talk</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512035" id="menu-item-1512035"><a href="https://www.rappler.com/video/reporters-vlogs/">Reports &amp; Vlogs</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512037" id="menu-item-1512037"><a href="https://www.rappler.com/video/video-explainers/">Video explainers</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1512038" id="menu-item-1512038"><a href="https://www.rappler.com/video/watch-now-live/">Watch NOW | Live</a></li>
# </ul>
# </div>
# </div><div class="burger-nav__panel burger-nav__sub-panel burger-nav__panel-depth-1" data-depth="1" id="submenu-panel-1511913">
# <div class="burger-nav__scrollable">
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1513212" id="menu-item-1513212"><a href="https://www.rappler.com/brandrap/">SEE ALL BRANDRAP</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511942" id="menu-item-1511942"><a href="https://www.rappler.com/brandrap/communicart/">CommuniCart</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511946" id="menu-item-1511946"><a href="https://www.rappler.com/brandrap/get-ready-with-me/">Get Ready With Me</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511940" id="menu-item-1511940"><a href="https://www.rappler.com/brandrap/announcements/">Announcements</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511941" id="menu-item-1511941"><a href="https://www.rappler.com/brandrap/beyond-the-buy/">Beyond the Buy</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511943" id="menu-item-1511943"><a href="https://www.rappler.com/brandrap/data-stories/">Data stories</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511944" id="menu-item-1511944"><a href="https://www.rappler.com/brandrap/detours/">Detours</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511945" id="menu-item-1511945"><a href="https://www.rappler.com/brandrap/finance-and-industries/">Finance and Industries</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511947" id="menu-item-1511947"><a href="https://www.rappler.com/brandrap/goodrap/">GoodRap</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511949" id="menu-item-1511949"><a href="https://www.rappler.com/brandrap/health-beauty-and-wellness/">Health, Beauty, and Wellness</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511950" id="menu-item-1511950"><a href="https://www.rappler.com/brandrap/home-and-parenting/">Home and Parenting</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1511951" id="menu-item-1511951"><a href="https://www.rappler.com/brandrap/lifestyle-and-entertainment/">Lifestyle and Entertainment</a></li>
# ...
# <svg fill="none" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M24 2.21484C24 1.39453 23.3203 0.714844 22.5 0.714844H1.5C0.679688 0.714844 0 1.39453 0 2.21484V23.2148C0 24.0352 0.679688 24.7148 1.5 24.7148H12.832V15.3867H9.83203V11.9297H12.832V8.94141C12.832 6.21094 14.4961 4.38281 17.7891 4.38281C19.2422 4.38281 20.25 4.54688 20.25 4.54688V7.66406H18C17.0039 7.66406 16.5 8.22656 16.5 9.21094V11.9297H20.0039L19.5 15.3867H16.5V24.7148H22.5C23.3203 24.7148 24 24.0352 24 23.2148V2.21484Z" fill="currentColor"></path>
# </svg>
# <span class="screen-reader-text">Facebook</span>
# </a>
# <a class="social-icon social-icon--twitter" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Frappler.com&amp;text=title&amp;via=rapplerdotcom&amp;utm_source=tw_share&amp;utm_medium=social" rel="noopener noreferrer" target="_blank">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M18.244 2.25h3.308l-7.227 8.26 8.502 11.24H16.17l-5.214-6.817L4.99 21.75H1.68l7.73-8.835L1.254 2.25H8.08l4.713 6.231zm-1.161 17.52h1.833L7.084 4.126H5.117z" fill="currentColor"></path>
# </svg>
# <span class="screen-reader-text">Twitter</span>
# </a>
# <button class="social-icon social-icon--share" data-permalink="https://rappler.com" data-title="title" type="button">
# <svg fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M16.0241 14.1365C15.2611 14.1365 14.5783 14.4378 14.0562 14.9096L6.8976 10.743C6.9478 10.512 6.98796 10.2811 6.98796 10.0402C6.98796 9.7992 6.9478 9.56827 6.8976 9.33735L13.9759 5.21084C14.5181 5.71285 15.2309 6.0241 16.0241 6.0241C17.6908 6.0241 19.0362 4.67871 19.0362 3.01205C19.0362 1.34538 17.6908 0 16.0241 0C14.3574 0 13.0121 1.34538 13.0121 3.01205C13.0121 3.25301 13.0522 3.48394 13.1024 3.71486L6.02411 7.84137C5.48194 7.33936 4.76909 7.02811 3.97592 7.02811C2.30925 7.02811 0.963867 8.37349 0.963867 10.0402C0.963867 11.7068 2.30925 13.0522 3.97592 13.0522C4.76909 13.0522 5.48194 12.741 6.02411 12.239L13.1727 16.4157C13.1225 16.6265 13.0924 16.8474 13.0924 17.0683C13.0924 18.6847 14.4076 20 16.0241 20C17.6406 20 18.9558 18.6847 18.9558 17.0683C18.9558 15.4518 17.6406 14.1365 16.0241 14.1365Z" fill="currentColor"></path>
# </svg>
# <span class="screen-reader-text">Share article</span>
# </button>
# <a class="social-icon social-icon--copy" data-permalink="https://rappler.com" href="https://rappler.com" rel="noopener noreferrer" type="button">
# <svg fill="none" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M22.0764 11.8204C24.6412 9.26724 24.6412 5.15647 22.0764 2.63847C19.5584 0.0736336 15.4476 0.0736336 12.8945 2.63847L9.17018 6.35105C6.65219 8.88076 6.65219 12.9915 9.17018 15.5447C9.75576 16.1302 10.7044 16.1302 11.2783 15.5447C11.899 14.9591 11.899 14.0104 11.2783 13.4366C9.91973 12.0429 9.91973 9.85282 11.2783 8.45914L15.026 4.74656C16.3962 3.38802 18.6097 3.38802 19.9683 4.74656C21.3268 6.10511 21.3268 8.3186 19.9683 9.68886L18.1998 11.4924C18.6449 12.687 18.8088 13.9285 18.6917 15.205L22.0764 11.8204ZM14.8386 19.0699C17.3566 16.5401 17.3566 12.4294 14.8386 9.87624C14.253 9.29066 13.281 9.29066 12.6954 9.87624C12.1098 10.4618 12.1098 11.4339 12.6954 12.0195C14.0891 13.378 14.0891 15.6032 12.6954 16.9618L8.9828 20.6743C7.61254 22.0329 5.39905 22.0329 4.0405 20.6743C2.68196 19.3158 2.68196 17.1023 4.0405 15.732L5.80895 13.9636C5.36391 12.769 5.19995 11.4924 5.31707 10.2159L1.89728 13.624C-0.632427 16.1537 -0.632427 20.2644 1.89728 22.8176C4.45041 25.3473 8.56118 25.3473 11.0909 22.8176L14.8386 19.0699Z" fill="currentColor"></path>
# </svg>
# <span class="screen-reader-text">Copy URL</span>
# </a>
# <div class="social-share__actions-tooltip">
# <span class="tooltip-dark">
# 			Copied		</span>
# </div>
# </div>
# </div>
# <div class="video-modal__link-container">
# <a class="video-modal__post-redirect">
# <div>READ</div>
# <svg fill="none" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.99984 0.5L0.589844 1.91L5.16984 6.5L0.589844 11.09L1.99984 12.5L7.99984 6.5L1.99984 0.5Z" fill="white"></path>
# </svg>
# </a>
# </div>
# </div>
# </div>
# </template>
# <div class="rappler-ad-container sticky-leaderboard">
# <div class="rappler-ad rappler-ad--sticky-leaderboard rappler-ad--desktop" id="gpt-sticky-leaderboard" style="min-width: 970px; min-height: 105px;">
# <div class="rappler-ad-placeholder" style="width: 728px; height: 90px;">
# </div>
# </div>
# <script>
# 									window.rapplerAds.displayAd( "sticky-leaderboard" );
# 							</script>
# </div>
# <div class="rappler-ad-container sticky-leaderboard">
# <div class="rappler-ad rappler-ad--mobile-sticky-leaderboard rappler-ad--mobile" id="gpt-mobile-sticky-leaderboard" style="min-width: 360px; min-height: 65px;">
# <div class="rappler-ad-placeholder" style="width: 320px; height: 50px;">
# </div>
# </div>
# <script>
# 									window.rapplerAds.displayAd( "mobile-sticky-leaderboard" );
# 							</script>
# </div>
# <script>
# 		(function() {
# 			document.querySelectorAll( '.sticky-leaderboard' ).forEach( function( stickyEl ) {
# 				// Create close button and append to container.
# 				var closeBtnEl = document.createElement( 'button' );
# 				closeBtnEl.appendChild( document.createTextNode( '×' ) );
# 				closeBtnEl.setAttribute( 'type', 'button ');
# 				closeBtnEl.classList.add( 'sticky-leaderboard__close' );
# 				stickyEl.appendChild( closeBtnEl );
#
# 				// On click, hide container.
# 				closeBtnEl.addEventListener( 'click', function() {
# 					stickyEl.classList.add( 'sticky-leaderboard--hidden' );
# 				} );
# 			} );
# 		} )();
# 	</script>
# <script id="lazy-load-scripts-footer-before">( function () {
# 	window.addEventListener( 'rappler-moodmeter-js-loaded', () => {
# 		window.waitForKeycloakInit().then(() => {
# 			const pianoId = window.keycloak?.authenticated && window.keycloak.idTokenParsed?.piano_id || 'guest';
#
# 			const mm = new MoodMeter({
# 				articleId: 2759297,
# 				username: "guest",
# 				pianoId: pianoId,
# 				cxenseId: 'cxense-1',
# 				deepId: 'deep-1'
# 			});
#
# 			mm.init();
# 		})
# 	} );
# } )();window._taboola = [{"container":"taboola-below-article-thumbnails","mode":"alternating-thumbnails-b","placement":"Below Article Thumbnails","target_type":"mix"},{"article":"auto"},{"flush":true}];</script><script id="rappler-theme-script-js-before">
# rapplerThemeData = {"restBase":"https:\/\/www.rappler.com\/wp-json\/"};
# </script>
# <script async="" id="rappler-theme-script-js" integrity="sha384-ZIXj3y6AJZqz/gILfkD4drP9UYReW7LrZ+PzT/hB2UaUJWd0wFNqWEz+LJk1E0AK" src="https://www.rappler.com/content/themes/rappler/build/rappler-theme-script.6ebbefb7fa892e802e00.js?ver=6ebbefb7fa892e802e00"></script>
# <script id="rappler-keycloak-js-before">
# rapplerKeycloak = {"elements":{".masthead":"masthead--logged-in",".burger-nav":"burger-nav--logged-in"},"logout_button":"","url":"https:\/\/sso.rappler.com","realm":"rappler","client_id":"rappler-web-client"};
# </script>
# <script id="rappler-keycloak-js" integrity="sha384-dWZChl9zAeXmmXAmp00cQg+B43cmzKRACAWV849cG09IppQQxqzE1BQq1BFgaKsH" src="https://www.rappler.com/content/mu-plugins/rappler-keycloak/assets/build/index.e8b3a884f2daed0c579e.js?ver=e8b3a884f2daed0c579e"></script>
# <script id="wp-polyfill-inert-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/wp-polyfill-inert.min.js?ver=3.1.2"></script>
# <script id="regenerator-runtime-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/regenerator-runtime.min.js?ver=0.13.11"></script>
# <script id="wp-polyfill-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=3.15.0"></script>
# <script id="wp-autop-js" src="https://www.rappler.com/wp-includes/js/dist/autop.min.js?ver=dacd785d109317df2707"></script>
# <script id="wp-blob-js" src="https://www.rappler.com/wp-includes/js/dist/blob.min.js?ver=10a1c5c0acdef3d15657"></script>
# <script id="wp-block-serialization-default-parser-js" src="https://www.rappler.com/wp-includes/js/dist/block-serialization-default-parser.min.js?ver=30ffd7e7e199f10b2a6d"></script>
# <script id="react-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/react.min.js?ver=18.2.0"></script>
# <script id="wp-hooks-js" src="https://www.rappler.com/wp-includes/js/dist/hooks.min.js?ver=c6aec9a8d4e5a5d543a1"></script>
# <script id="wp-deprecated-js" src="https://www.rappler.com/wp-includes/js/dist/deprecated.min.js?ver=73ad3591e7bc95f4777a"></script>
# <script id="wp-dom-js" src="https://www.rappler.com/wp-includes/js/dist/dom.min.js?ver=845eabf47b55af03adfa"></script>
# <script id="react-dom-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/react-dom.min.js?ver=18.2.0"></script>
# <script id="wp-escape-html-js" src="https://www.rappler.com/wp-includes/js/dist/escape-html.min.js?ver=03e27a7b6ae14f7afaa6"></script>
# <script id="wp-element-js" src="https://www.rappler.com/wp-includes/js/dist/element.min.js?ver=ed1c7604880e8b574b40"></script>
# <script id="wp-is-shallow-equal-js" src="https://www.rappler.com/wp-includes/js/dist/is-shallow-equal.min.js?ver=20c2b06ecf04afb14fee"></script>
# <script id="wp-i18n-js" src="https://www.rappler.com/wp-includes/js/dist/i18n.min.js?ver=7701b0c3857f914212ef"></script>
# <script id="wp-i18n-js-after">
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# </script>
# <script id="wp-keycodes-js" src="https://www.rappler.com/wp-includes/js/dist/keycodes.min.js?ver=3460bd0fac9859d6886c"></script>
# <script id="wp-priority-queue-js" src="https://www.rappler.com/wp-includes/js/dist/priority-queue.min.js?ver=422e19e9d48b269c5219"></script>
# <script id="wp-compose-js" src="https://www.rappler.com/wp-includes/js/dist/compose.min.js?ver=9424edf50a26435105c0"></script>
# <script id="wp-private-apis-js" src="https://www.rappler.com/wp-includes/js/dist/private-apis.min.js?ver=c7aedd57ea3c9b334e7d"></script>
# <script id="wp-redux-routine-js" src="https://www.rappler.com/wp-includes/js/dist/redux-routine.min.js?ver=0be1b2a6a79703e28531"></script>
# <script id="wp-data-js" src="https://www.rappler.com/wp-includes/js/dist/data.min.js?ver=1504e29349b8a9d1ae51"></script>
# <script id="wp-data-js-after">
# ( function() {
# 	var userId = 0;
# 	var storageKey = "WP_DATA_USER_" + userId;
# 	wp.data
# 		.use( wp.data.plugins.persistence, { storageKey: storageKey } );
# } )();
# </script>
# <script id="wp-html-entities-js" src="https://www.rappler.com/wp-includes/js/dist/html-entities.min.js?ver=36a4a255da7dd2e1bf8e"></script>
# <script id="wp-shortcode-js" src="https://www.rappler.com/wp-includes/js/dist/shortcode.min.js?ver=c128a3008a96e820aa86"></script>
# <script id="wp-blocks-js" src="https://www.rappler.com/wp-includes/js/dist/blocks.min.js?ver=b5d3b99262dfb659bd26"></script>
# <script id="wp-dom-ready-js" src="https://www.rappler.com/wp-includes/js/dist/dom-ready.min.js?ver=392bdd43726760d1f3ca"></script>
# <script id="wp-a11y-js" src="https://www.rappler.com/wp-includes/js/dist/a11y.min.js?ver=7032343a947cfccf5608"></script>
# <script id="moment-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/moment.min.js?ver=2.29.4"></script>
# <script id="moment-js-after">
# moment.updateLocale( 'en_US', {"months":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthsShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"weekdays":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"weekdaysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"week":{"dow":1},"longDateFormat":{"LT":"g:i a","LTS":null,"L":null,"LL":"F j, Y","LLL":"F j, Y g:i a","LLLL":null}} );
# </script>
# <script id="wp-date-js" src="https://www.rappler.com/wp-includes/js/dist/date.min.js?ver=505e060585ac0f4b6cb6"></script>
# <script id="wp-date-js-after">
# wp.date.setSettings( {"l10n":{"locale":"en_US","months":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthsShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"weekdays":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"weekdaysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"meridiem":{"am":"am","pm":"pm","AM":"AM","PM":"PM"},"relative":{"future":"%s from now","past":"%s ago"},"startOfWeek":1},"formats":{"time":"g:i a","date":"F j, Y","datetime":"F j, Y g:i a","datetimeAbbreviated":"M j, Y g:i a"},"timezone":{"offset":8,"string":"","abbr":""}} );
# </script>
# <script id="wp-primitives-js" src="https://www.rappler.com/wp-includes/js/dist/primitives.min.js?ver=b90ba9340ccd8dae04b5"></script>
# <script id="wp-rich-text-js" src="https://www.rappler.com/wp-includes/js/dist/rich-text.min.js?ver=477e6aed00daeb0e4ab6"></script>
# <script id="wp-warning-js" src="https://www.rappler.com/wp-includes/js/dist/warning.min.js?ver=4acee5fc2fd9a24cefc2"></script>
# <script id="wp-components-js" src="https://www.rappler.com/wp-includes/js/dist/components.min.js?ver=0f16bd3719000192197f"></script>
# <script id="client-three-point-summary-js-extra">
# var wpServerData = {"apiRoute":"\/wp-json\/summary\/v1\/update-post-meta","postId":"2759297"};
# </script>
# <script id="client-three-point-summary-js" integrity="sha384-4P/3Au7QDcIUOqSNlKzjFozidKea0zVDHSTDTe3xpZnfqVyhjQy5xuEZNWauNfmu" src="https://www.rappler.com/content/themes/rappler/build/client-three-point-summary.e0c139a88f022050748d.js?ver=e0c139a88f022050748d"></script>
# <script id="lazy-load-scripts-js-before">
# var lazyLoadScriptsEntries = [{"element_selectors":".container","offset":"0px","script_id":"rappler-cxense-widget-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-cxense\/build\/rappler-cxense-widget.8b26a0b2fce60e965f8c.js","script_async":false},{"element_selectors":".site-header, #burger-navigation, #rappler-comments","offset":"0px","script_id":"rappler-piano-js","script_src":"https:\/\/experience-ap.piano.io\/xbuilder\/experience\/load?aid=CS7qljxwpj","script_async":true},{"element_selectors":".site-header, #burger-navigation, #rappler-comments","offset":"0px","script_id":"rappler-piano-init-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-piano\/assets\/build\/rappler-piano-init.2ea8d39d7f55cb79a91e.js","script_async":true},{"element_selectors":"#rappler-speechify","offset":"0px","script_id":"rappler-speechify-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-speechify\/assets\/build\/index.c080d8d1749e24ef271f.js","script_async":true},{"element_selectors":".latest-videos, .video-article-content-container, .youtube-video, .carousel--videos, .developing-stories__feed","offset":"100px","script_id":"rappler-youtube-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-youtube\/assets\/build\/rappler-youtube.81c3a7bf35d87d5f8aec.js","script_async":false},{"element_selectors":".dailymotion-container","offset":"800px","script_id":"rappler-dailymotion-js","script_src":"https:\/\/srvr.dmvs-apac.com\/v2\/dm-ce.min.js","script_async":false},{"element_selectors":"#rappler-comments","offset":"300px","script_id":"rappler-comments-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-comments\/assets\/build\/index.d44b0585d7f1ebcdf291.js","script_async":false},{"element_selectors":"#moodmeter","offset":"0px","script_id":"rappler-moodmeter-js","script_src":"https:\/\/mm-widget-production.rappler.com","script_async":false},{"element_selectors":"#taboola-below-article-thumbnails","offset":"1000px","script_id":"rappler-taboola-js","script_src":"\/\/cdn.taboola.com\/libtrc\/rappler-rappler\/loader.js","script_async":false}];
# </script>
# <script async="" id="lazy-load-scripts-js" integrity="sha384-vFyz2f3JEfwsTWE0FDUo6sKIlDxaEbx2MvpjqMo6ulhQz50n4WpUsDE42Sq1S8df" src="https://www.rappler.com/content/mu-plugins/lazy-load-scripts/assets/build/main.5194775d182c57153c00.js?ver=5194775d182c57153c00"></script>
# </body>
# </html>
# <!--
# 	generated in 2.222 seconds
# 	462861 bytes batcached for 300 seconds
# -->

# %% [markdown]
# We'll extract the following information to create our corpus.
# * article link
# * article title
# * date published
# * article's text / body
# * *optional*: tags, i.e., related topic

# %% [markdown]
# ## Extract the webpage's title.

# %%
soup.title  # with HTML tags
soup.title.text  # text within the HTML tags
title = soup.title.text.strip()  # whitespaces are removed

# %% [markdown]
# ## Extract the webpage's date published.

# %%
# Date published
date_published = soup.find(
  'time',  # HTML element tag
  {
      'class': 'published',
      'datetime': True
  }  # HTML attribute
)
# Actual text within the HTML element
date_published.text.strip()

# If you're after the HTML attribute, use the attribute name for the key
date_published = date_published['datetime']

# %% [markdown]
# ## Extract the webpage's text

# %%
# Extract article text
# element: div
# class: post-single__content entry-content
article_text = soup.find(
  'div',  # HTML element tag
  {
      'class': 'post-single__content entry-content'
  }  # HTML attribute
)
# Returns the HTML code for the article
article_text

# Get all paragraph (<p>) from the article_text
tagged_lines = article_text.find_all('p')  # Return list of paragraph elements

# Removes the HTML tags
text = ''
for line in tagged_lines:
  untagged_line = line.get_text()
  text += untagged_line + '\n'

# Returns the article text as 1 big string
print(text)
# Out:
# Claim: The face of Vice President Sara Duterte is not in the children’s book that she wrote titled, “Isang Kaibigan“.
# Why we fact-checked this: The claim can be found in an August 21 post on social media platform X (formerly Twitter). The post says: “Yung libro na ni anino ni VPISD eh wala nga dyan” (The book that does not bear even a hint of a shadow of VPISD [Vice President Inday Sara Duterte] is not there).
# The post also includes a video from the TikTok account “klc4.0” which — referring to Duterte’s book, Isang Kaibigan — says: “Yung libro ni Sara Duterte na walang mukha niya” (The book of Sara Duterte that does not carry her face).
# As of writing, the post on X already has around 51 comments, 50 shares, 135 reactions, 7 bookmarks, and 23,800 video views. The source video on TikTok, meanwhile, has around 198,700 views, 3,690 reactions, 1,076 comments, 226 bookmarks, and 138 shares.
# Both the X post and the TikTok video compare Sara Duterte and Senator Risa Hontiveros, pointing out the supposed absence of Duterte’s face in her book unlike Hontiveros whose face is supposedly on billboards and buses.
# The facts: Vice President Sara Duterte’s book, “Isang Kaibigan” actually shows her face at the end of the book.
# Numerous news reports have shown the page of the book that contains Duterte’s picture, along with some biographical details and the statement, “Siya ay isang tunay na kaibigan” (She is a true friend). Examples are news articles published on August 21 by Rappler, Philstar.com, and Inquirer.net.
# What’s the issue: The controversy over the book arose during the August 20 budget hearing for the Office of the Vice President’s (OVP) proposed 2025 budget. Senator Hontiveros asked Duterte about the book for which the OVP allotted a P10-million budget for printing and distribution.
# Duterte, however, replied, accusing Hontiveros of “politicizing the budget hearing.” This did not sit well with senator, who later on told Duterte: “Budget hearing po ito. Hindi po lahat about you. Pera po ito ng taong bayan.” (This is a budget hearing. Not everything is about you. This is about public funds.) (READ: Rappler Recap: Sara Duterte, Risa Hontiveros clash during Senate budget hearing)
# Duterte’s book is about an owl (Kwago) with many friends. A storm damaged the owl’s home; with the others gone, one of the owl’s friends, a parrot (Loro), offered to help the owl recover from the storm’s effects. – Percival Bueser/ Rappler.com
# Percival Bueser is a graduate of Rappler’s fact-checking mentorship program. This fact check was reviewed by a member of Rappler’s research team and a senior editor. Learn more about Rappler’s fact-checking mentorship program here.
# Keep us aware of suspicious Facebook pages, groups, accounts, websites, articles, or photos in your network by contacting us at factcheck@rappler.com. You may also report dubious claims to #FactsFirstPH tipline by messaging Rappler on Facebook or Newsbreak via Twitter direct message. You may also report through our Viber fact check chatbot. Let us battle disinformation one Fact Check at a time.

# %% [markdown]
# ## Combine features into dataframe

# %%
# Link
# Title
# Date Published
# Article's Text
rappler = pd.DataFrame(
    columns=['title', 'link', 'date_published', 'text']
)
doc_details = [title, link, date_published, text]
rappler.loc[len(rappler)] = doc_details
rappler
# Out:
#                                                title  \
# 0  FACT CHECK: VP Sara Duterte's face is in her b...
#
#                                                 link  \
# 0  https://www.rappler.com/newsbreak/fact-check/s...
#
#               date_published  \
# 0  2024-08-22T20:11:07+08:00
#
#                                                 text
# 0  Claim: The face of Vice President Sara Duterte...

# %% [markdown]
# ## Export to Excel file

# %%
try:
  # Google Colab
  from google.colab import drive
  drive.mount('/content/drive')

  file_name = '/content/drive/MyDrive/rappler.xlsx'
except:
  # VS Code / Local machine
  file_name = 'rappler.xlsx'

rappler.to_excel(file_name)
print(f'File saved to {file_name}')
# Out:
# File saved to rappler.xlsx

# %% [markdown]
# ## Function `extract_article_data`

# %%
# Extract data from article based on link
def extract_article_data(link):
  """
  Extracts data from an article based on the provided link.

  Parameters:
    link (str): The URL of the article.

  Returns:
    list: A list containing the extracted article details in the following order:
      - title (str): The title of the article.
      - date (str): The date the article was published.
      - link (str): The URL of the article.
      - text (str): The content of the article.
  """
  # Make a GET request for the article URL
  r = requests.get(link, headers=headers)

  # Parse the HTML
  soup = BeautifulSoup(r.content, 'html.parser')

  # Retrieve doc title
  title = soup.title.text.strip()

  # IF NOT WITH RAPPLER ARTICLE, CHANGE THIS XOXO
  # Retrieve doc date
  date = soup.find("time", {"datetime": True})['datetime']

  # IF NOT WITH RAPPLER ARTICLE, CHANGE THIS XOXO
  # Retrieve article content
  text = ''
  tagged_lines = soup.find("div", {"class": "post-single__content entry-content"}).find_all('p')
  for line in tagged_lines:
    untagged_line = line.get_text()
    text += untagged_line + '\n'

  # Create list containing doc details
  # Append to dataset
  doc_details = [title, date, link, text]
  return doc_details

# %%
# Test the `extract_article_data` function
rappler.loc[len(rappler)] = extract_article_data(
  'https://www.rappler.com/philippines/hontiveros-seek-realignment-sara-duterte-book-fund-request-2025-budget/'
)
rappler
# Out:
#                                                title  \
# 0  FACT CHECK: VP Sara Duterte's face is in her b...
# 1  Hontiveros to seek realignment of Sara Duterte...
#
#                                                 link  \
# 0  https://www.rappler.com/newsbreak/fact-check/s...
# 1                          2024-08-22T13:05:55+08:00
#
#                                       date_published  \
# 0                          2024-08-22T20:11:07+08:00
# 1  https://www.rappler.com/philippines/hontiveros...
#
#                                                 text
# 0  Claim: The face of Vice President Sara Duterte...
# 1  MANILA, Philippines – Senator Risa Hontiveros ...

# %% [markdown]
# ## Extracting Multiple Articles

# %%
mother_url = 'https://www.rappler.com/topic/philippine-offshore-gaming-operations/page/'
page = 1
page_limit = 5
corpus = pd.DataFrame(columns=['title', 'link', 'date_published', 'text'])

while True:
  if page == 1:
    # Remove 'page/' at the end of mother_url
    page_url = mother_url[:-6]
  else:
    # Convert page number as a string
    page_str = str(page)
    # Form the article page
    page_url = mother_url + page_str
  print('Working on ' + page_url)

  # Add random time between 1 to 5 seconds before requesting
  time.sleep(random.randint(1, 5))

  # Get the list of articles within the page
  page_r = requests.get(page_url, headers=headers)
  page_soup = BeautifulSoup(page_r.content, 'html.parser')

  # Get the container of the articles
  article_container = page_soup.find('div', {'id': 'primary'})
  if article_container is None:
    continue

  article_previews = article_container.find_all('article', {'class': 'post'})
  number_of_articles = len(article_previews)

  # If no article/s found, end
  if number_of_articles < 1:
    print('Extraction Finished!')
    break

  # Go through each article to extract and save to the dataframe
  for article_id in range(number_of_articles):
    # Focus on the article preview
    article = article_previews[article_id]
    # Get the clickable article title
    article_title = article.find("h2")

    # If no title, skip
    if article_title is None:
      continue

    # For each articles, invoke `extract_article_data`
    try:
      # Append to a dataframe
      corpus.loc[len(corpus)] = extract_article_data(article_title.find("a")['href'])
    except:
      # if there's an extraction error, skip
      continue

  # Check whether you have reached the page limit
  if page >= page_limit:
    break

  # Go to the next page
  page += 1
# Out:
# Working on https://www.rappler.com/topic/philippine-offshore-gaming-operations
# Working on https://www.rappler.com/topic/philippine-offshore-gaming-operations/page/2
# Working on https://www.rappler.com/topic/philippine-offshore-gaming-operations/page/3
# Working on https://www.rappler.com/topic/philippine-offshore-gaming-operations/page/4
# Working on https://www.rappler.com/topic/philippine-offshore-gaming-operations/page/5

# %%
try:
  # Google Colab
  from google.colab import drive
  drive.mount('/content/drive')

  file_name = '/content/drive/MyDrive/rappler_corpus.xlsx'
except:
  # VS Code / Local machine
  file_name = 'rappler_corpus.xlsx'

corpus.to_excel(file_name)
print(f'File saved to {file_name}')
# Out:
# File saved to rappler_corpus.xlsx

# %%
corpus
# Out:
#                                                 title  \
# 0   DOJ on 'slow' pace of Alice Guo case: 'We cann...
# 1   Lawyer who notarized Alice Guo's counter affid...
# 2     Alice Guo and siblings fled Philippines by boat
# 3   Alice Guo's sister, Porac POGO staff to face S...
# 4   Cassandra Ong, Sheila Guo in Congress custody ...
# 5   In the Golden Triangle, a Filipino was told 'y...
# 6             House detains POGO worker Cassandra Ong
# 7   Harry Roque's 'footprint is everywhere' in POG...
# 8   Harry Roque, from party-list congressman to en...
# 9   Shades of gray: How PH ended up with a POGO cr...
# 10  House quad committee defends move to detain Ha...
# 11     Harry Roque released from House detention cell
# 12     What happens now to Sheila Guo, Cassandra Ong?
# 13  WATCH: Cassandra Ong, Sheila Guo arrive in PH ...
# 14  House detains Harry Roque for 'lying' to lawma...
# 15  Alice Guo's sister, Porac POGO worker Cassandr...
# 16  How did Alice go to Malaysia, Singapore, Indon...
# 17  Marcos vows ‘heads will roll’ after Alice Guo’...
# 18  How Alice Guo concealed POGO link when she was...
# 19  Ex-customs official links Dutertes, Michael Ya...
# 20  House mega-panel cites Cassandra Ong, tied to ...
# 21  BIR files tax evasion complaint vs Mayor Alice...
# 22  5 key moments from Day 4 of House probe into P...
# 23  House detains corporate secretary of raided PO...
# 24  House forms 'quad comm' to probe links between...
# 25  House panel links POGOs to drug operations in ...
# 26          Harry Roque is now on immigration lookout
# 27  Rappler Recap: In Central Luzon visit, House l...
# 28  House probe: Roque ‘effectively’ lawyered for ...
# 29  [WATCH] Inside Track: Who fired the Bamban POG...
# 30  Before Duterte's POGO, Cagayan had 'i-Gaming.'...
# 31  BPOs, corporate firms expected to offset offic...
# 32  No POGOs inside Cagayan special economic zone,...
# 33           10 Chinese POGO workers rescued in Clark
# 34  Petition to unseat Alice Guo as Bamban mayor f...
# 35  Chinese fugitive caught in Benguet house linke...
# 36  Pagcor: Internet Gaming Licensees covered by M...
# 37  Philippine gov't seeks to unseat Alice Guo as ...
# 38  [In This Economy] Marcos’ POGO ban is popular,...
# 39  [Rappler Investigates] POGOs no-go as Typhoon ...
# 40       Newsbreak Chats: POGO ban — making it happen
# 41    Metro Manila under state of calamity | The wRap
# 42  Philippines orders foreign workers in offshore...
# 43  DOLE to help find jobs for displaced POGO workers
# 44  Marcos’ POGO ban welcomed by Filipinos | The wRap
# 45  Romualdez orders House leaders to introduce me...
# 46    [Just Saying] SONA 2024: Some disturbing points
# 47           Which POGOs are affected by Marcos' ban?
# 48  Pampanga officials, business leaders support M...
#
#                          link  \
# 0   2024-08-28T10:24:17+08:00
# 1   2024-08-28T07:00:00+08:00
# 2   2024-08-27T13:20:33+08:00
# 3   2024-08-27T10:03:09+08:00
# 4   2024-08-26T21:53:00+08:00
# 5   2024-08-26T17:51:50+08:00
# 6   2024-08-26T14:38:08+08:00
# 7   2024-08-24T19:02:20+08:00
# 8   2024-08-24T14:25:05+08:00
# 9   2024-08-24T09:30:00+08:00
# 10  2024-08-23T22:25:00+08:00
# 11  2024-08-23T21:37:02+08:00
# 12  2024-08-23T20:34:15+08:00
# 13  2024-08-22T19:07:45+08:00
# 14  2024-08-22T18:47:03+08:00
# 15  2024-08-22T11:09:05+08:00
# 16  2024-08-21T09:37:50+08:00
# 17  2024-08-21T09:16:18+08:00
# 18  2024-08-19T14:08:27+08:00
# 19  2024-08-16T21:34:16+08:00
# 20  2024-08-16T19:11:22+08:00
# 21  2024-08-14T10:39:43+08:00
# 22  2024-08-08T14:36:12+08:00
# 23  2024-08-07T18:23:02+08:00
# 24  2024-08-07T13:12:00+08:00
# 25  2024-08-06T17:55:00+08:00
# 26  2024-08-06T16:25:18+08:00
# 27  2024-08-05T21:51:29+08:00
# 28  2024-08-02T22:10:09+08:00
# 29  2024-08-02T19:29:30+08:00
# 30  2024-08-01T19:44:57+08:00
# 31  2024-07-31T20:25:35+08:00
# 32  2024-07-31T17:40:23+08:00
# 33  2024-07-31T11:14:17+08:00
# 34  2024-07-29T22:17:00+08:00
# 35  2024-07-29T20:08:15+08:00
# 36  2024-07-29T13:40:49+08:00
# 37  2024-07-29T11:27:47+08:00
# 38  2024-07-26T15:00:00+08:00
# 39  2024-07-26T10:00:00+08:00
# 40  2024-07-25T16:00:00+08:00
# 41  2024-07-24T22:46:53+08:00
# 42  2024-07-24T14:34:17+08:00
# 43  2024-07-24T13:58:57+08:00
# 44  2024-07-23T22:16:00+08:00
# 45  2024-07-23T16:14:24+08:00
# 46  2024-07-23T14:24:22+08:00
# 47  2024-07-23T11:36:37+08:00
# 48  2024-07-23T10:00:00+08:00
#
#                                        date_published  \
# 0   https://www.rappler.com/philippines/doj-respon...
# 1   https://www.rappler.com/philippines/lawyer-not...
# 2   https://www.rappler.com/philippines/alice-guo-...
# 3   https://www.rappler.com/philippines/alice-guo-...
# 4   https://www.rappler.com/video/daily-wrap/augus...
# 5   https://www.rappler.com/newsbreak/in-depth/gol...
# 6   https://www.rappler.com/philippines/house-deta...
# 7   https://www.rappler.com/philippines/harry-roqu...
# 8   https://www.rappler.com/newsbreak/in-depth/pro...
# 9   https://www.rappler.com/newsbreak/in-depth/sha...
# 10  https://www.rappler.com/video/daily-wrap/augus...
# 11  https://www.rappler.com/philippines/harry-roqu...
# 12  https://www.rappler.com/newsbreak/explainers/w...
# 13  https://www.rappler.com/philippines/video-cass...
# 14  https://www.rappler.com/philippines/house-repr...
# 15  https://www.rappler.com/philippines/katherine-...
# 16  https://www.rappler.com/newsbreak/in-depth/how...
# 17  https://www.rappler.com/philippines/marcos-sta...
# 18  https://www.rappler.com/newsbreak/inside-track...
# 19  https://www.rappler.com/philippines/luzon/ex-c...
# 20  https://www.rappler.com/philippines/house-pane...
# 21  https://www.rappler.com/philippines/bir-files-...
# 22  https://www.rappler.com/philippines/house-repr...
# 23  https://www.rappler.com/philippines/house-repr...
# 24  https://www.rappler.com/philippines/house-repr...
# 25  https://www.rappler.com/philippines/luzon/hous...
# 26  https://www.rappler.com/philippines/harry-roqu...
# 27  https://www.rappler.com/philippines/luzon/vide...
# 28  https://www.rappler.com/newsbreak/inside-track...
# 29  https://www.rappler.com/newsbreak/podcasts-vid...
# 30  https://www.rappler.com/newsbreak/in-depth/bef...
# 31  https://www.rappler.com/business/bpos-traditio...
# 32  https://www.rappler.com/philippines/luzon/ceza...
# 33  https://www.rappler.com/philippines/luzon/chin...
# 34  https://www.rappler.com/video/daily-wrap/july-...
# 35  https://www.rappler.com/philippines/chinese-fu...
# 36  https://www.rappler.com/philippines/pagcor-say...
# 37  https://www.rappler.com/philippines/office-sol...
# 38  https://www.rappler.com/voices/thought-leaders...
# 39  https://www.rappler.com/voices/investigates-po...
# 40  https://www.rappler.com/newsbreak/podcasts-vid...
# 41  https://www.rappler.com/video/daily-wrap/july-...
# 42  https://www.rappler.com/philippines/foreign-wo...
# 43  https://www.rappler.com/business/dole-help-fin...
# 44  https://www.rappler.com/video/daily-wrap/july-...
# 45  https://www.rappler.com/philippines/house-spea...
# 46  https://www.rappler.com/voices/thought-leaders...
# 47  https://www.rappler.com/business/which-pogos-a...
# 48  https://www.rappler.com/philippines/luzon/pamp...
#
#                                                  text
# 0   MANILA, Philippines – The Department of Justic...
# 1   CLARK FREEPORT, Philippines – The lawyer who n...
# 2   MANILA, Philippines – Dismissed Bamban, Tarlac...
# 3   MANILA, Philippines – After an embarrassing la...
# 4   Here are today’s headlines – the latest news i...
# 5   You cannot go home, you will die here,” are wo...
# 6   MANILA, Philippines – The National Bureau of I...
# 7   MANILA, Philippines – Former presidential spok...
# 8   In the words of Harry Roque, the House of Repr...
# 9   It was June 30, 2016, when Rodrigo Duterte, th...
# 10  Here are today’s headlines – the latest news i...
# 11  MANILA, Philippines – Former presidential spok...
# 12  The Philippine offshore gaming operator (POGO)...
# 13  MANILA, Philippines – Katherine Cassandra Ong,...
# 14  MANILA, Philippines – A House mega panel inves...
# 15  MANILA, Philippines – Katherine Cassandra Ong,...
# 16  The most controversial mayor in the Philippine...
# 17  MANILA, Philippines – President Ferdinand Marc...
# 18  Alice Guo, in her statements before she disapp...
# 19  PAMPANGA, Philippines – Jimmy Guban, a former ...
# 20  MANILA, Philippines – The House of Representat...
# 21  MANILA, Philippines – The Bureau of Internal R...
# 22  MANILA, Philippines – The fourth day of the Ho...
# 23  MANILA, Philippines – The House of Representat...
# 24  MANILA, Philippines – The House of Representat...
# 25  PAMPANGA, Philippines — There is a strong conn...
# 26  MANILA, Philippines – The Philippine governmen...
# 27  PAMPANGA, Philippines – Key officials of the H...
# 28  Harry Roque, a former human rights lawyer and ...
# 29  The Presidential Anti-Organized Crime Commissi...
# 30  Ulysis, not his real name, tried to uncuff him...
# 31  MANILA, Philippines – Although Philippine offs...
# 32  PAMPANGA, Philippines – “There are no POGOs (P...
# 33  CLARK FREEPORT, Philippines – Ten Chinese men ...
# 34  Here are today’s headlines – the latest news i...
# 35  MANILA, Philippines – The man caught in a hous...
# 36  MANILA, Philippines – The 44 Internet Gaming L...
# 37  MANILA, Philippines – The Philippine governmen...
# 38  “Effective today, all POGOs are banned.”\nThat...
# 39  I hope you and members of your family are all ...
# 40  MANILA, Philippines – President Ferdinand Marc...
# 41  Here are today’s headlines – the latest news i...
# 42  MANILA, Philippines – The Philippines has orde...
# 43  MANILA, Philippines – The Department of Labor ...
# 44  Here are today’s headlines – the latest news i...
# 45  MANILA, Philippines – House Speaker Martin Rom...
# 46  President Marcos Jr. started his speech correc...
# 47  MANILA, Philippines – Which gaming operators a...
# 48  PAMPANGA, Philippines – President Ferdinand Ma...

# %% [markdown]
# # Method 2: Using the YouTube API

# %% [markdown]
# ## Create YouTube Data API v3 key

# %% [markdown]
# Before we can scrape data from YouTube, we need to get an API key. APIs, or Application Programming Interfaces, are ways in which two applications (e.g., Google Colaboratory and YouTube) can talk to each other. You can think of it as the language through which two apps can speak so they can send and receive information from each other.
#
# Some apps (e.g., YouTube and Google services) require an API key, or a string of characters that authenticates a user to access the app through an API.

# %% [markdown]
# 1.   To get your API key, head to https://console.cloud.google.com/cloud-resource-manager
# 2.   Click on Create Project, name the project "YouTube scraping," and press "CREATE"
# 3.   In your Google Developers Console dashboard, click the Navigation Menu (the three lines) at the upper left corner and select "APIs & Services"
# 4.   When prompted, select the "YouTube scraping" project
# 5.   You will be directed to the project's dashboard, where you are to click "Explore & Enable APIs"
# 6.   Search for and select "YouTube Data API v3"
# 7.   Enable the API and click "Create Credentials"
# 8.   Select "public data" when asked what kind of data you will access
# 9.   Find your API key at the "Credentials" tab on the left side of your dashboard (If it's not there, just click "Create Credentials" again and select "API key")

# %% [markdown]
# Now, we import the pertinent packages.
#
# `build` creates a resource object that uses the API key to communicate with YouTube.

# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyArJa4h3CPtJILqexIrRWL22W7K1ZzxABs'
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Let's make it our goal to make a corpus based on YouTube comments about Alice Guo.
# Let's start with this link: https://www.youtube.com/watch?v=yfoq-0gGTLM

# %% [markdown]
# To get comment thread results from YouTube, we execute the code below that uses the `commentThreads()` and `list` methods with two arguments:
# *   `id`, which we get from the link above
# *   `parts`, which we set as "snippet,replies" because these are the only parts of the comment results we are interested in
#
# To learn more about how to use the YouTube API to get comment thread results, refer to https://developers.google.com/youtube/v3/docs/commentThreads/list

# %% [markdown]
# Now, let's try and look at the contents of the video_response object.

# %% [markdown]
# ## Extract the YouTube comments

# %%
video_id = 'yfoq-0gGTLM'
video_response = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time'
).execute()
video_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'h6GG2Ymhk7BukQ66l1nfYBYSjFo',
#  'pageInfo': {'totalResults': 25, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'KwQ8MckUnNNTj0heexX_ywyh6sc',
#    'id': 'UgzmI6rrrSbY2I4XZTd4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BNE0HFymQ4Vds3IsOY1HDEtwem8',
#      'id': 'UgzmI6rrrSbY2I4XZTd4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Ang kapalpakan ng marcos admin lumaganap na ulit ang droga kay duterte oarin isinisisi, may god i hate cocaine.',
#       'textOriginal': 'Ang kapalpakan ng marcos admin lumaganap na ulit ang droga kay duterte oarin isinisisi, may god i hate cocaine.',
#       'authorDisplayName': '@2littlebee1',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ndI6ZouWopQgS2uB15Ofp0k1WFDSPMH9F5_xSaGgz16sk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@2littlebee1',
#       'authorChannelId': {'value': 'UCKi4zLPRj1ChJmYfyIHKvkA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-28T11:55:23Z',
#       'updatedAt': '2024-08-28T11:55:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'atzcSZ92dThs8XE_C13dqxjnizk',
#    'id': 'Ugy0BGFxyIeX1JO5FN94AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3JcDaBCXVMtWesvJDTEL2lGoHQQ',
#      'id': 'Ugy0BGFxyIeX1JO5FN94AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Only this type of human race can go anywhere in asia because they have strong connections anywhere in asia 😅',
#       'textOriginal': 'Only this type of human race can go anywhere in asia because they have strong connections anywhere in asia 😅',
#       'authorDisplayName': '@user-em3xb4hk2k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kOb7QQDcZFwpMIdd9bTrXMar1ggASA-XZvBJ1dsoZ7ILZXnMflzIOdl1i8MGKOzZIN6g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-em3xb4hk2k',
#       'authorChannelId': {'value': 'UCAK1B7NmLc29aw63pDMTB1Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T23:12:34Z',
#       'updatedAt': '2024-08-27T23:12:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qXRnsyjc62yP1u1o7N0nRvf6jxs',
#    'id': 'UgyRuVLLOfb4WLNYKSZ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'qRP0Zc9tG-bJBvd4PL93HwZJulc',
#      'id': 'UgyRuVLLOfb4WLNYKSZ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Mga duterte puro angas wala naman gawa',
#       'textOriginal': 'Mga duterte puro angas wala naman gawa',
#       'authorDisplayName': '@johnhasidlethoughts',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_loZRoHoXnZMQrh-l6cyig53o8C6L9fxmJr4GaK--y2IQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@johnhasidlethoughts',
#       'authorChannelId': {'value': 'UC3_le0UDIFZDmy-URVc8B5Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T22:36:52Z',
#       'updatedAt': '2024-08-27T22:36:52Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zK64IyvHkX4nkDJ-lX1vI_dPuvM',
#    'id': 'UgxO6U2o-uAKPSN28B94AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OyG_KMZLD_5qzPOIC1DLeFDOHvw',
#      'id': 'UgxO6U2o-uAKPSN28B94AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Now that you know she is in Jakarta what is the relevant move of the Philippine Government?  When she was still in the Philippines Alice Guo was so elusive for the arrest warrant now she is in Jakarta how can she be caught? The whole world is under the spell of this deceitful person making the Philippines her toy country. And her Atty. David ? Whew! What a mockery on the Philippine Government in its entirety.',
#       'textOriginal': 'Now that you know she is in Jakarta what is the relevant move of the Philippine Government?  When she was still in the Philippines Alice Guo was so elusive for the arrest warrant now she is in Jakarta how can she be caught? The whole world is under the spell of this deceitful person making the Philippines her toy country. And her Atty. David ? Whew! What a mockery on the Philippine Government in its entirety.',
#       'authorDisplayName': '@wilmabodis9365',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mvt9y1mxKEpZCoUa-jXaVETiIND2OtbZr60_oR8w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@wilmabodis9365',
#       'authorChannelId': {'value': 'UCeohFb3ut5t291xTP8I_iZA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T21:59:23Z',
#       'updatedAt': '2024-08-27T21:59:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'SaghYLyMaSR5HmQQHL4kXUYsvMs',
#    'id': 'UgzamKARBiFjay61gJd4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MWSOuXDvyXboinIo0U5wUYMp5Jk',
#      'id': 'UgzamKARBiFjay61gJd4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Huliin na po!',
#       'textOriginal': 'Huliin na po!',
#       'authorDisplayName': '@criscris8690',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mpqex2oiJBxBq7UlNpjkYADZDSny4Hsu9eeCgTNGQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@criscris8690',
#       'authorChannelId': {'value': 'UCwLIcnIiwoagDIm6ZRmn5Eg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T21:05:23Z',
#       'updatedAt': '2024-08-27T21:05:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fTtOxDzMIWRh1YnSp2t1X9owhvU',
#    'id': 'Ugy8dvTUCeWPWjA1EgB4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Pe6mBSSo1NZPHokOerDB5UWw3gk',
#      'id': 'Ugy8dvTUCeWPWjA1EgB4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'duterte never again.',
#       'textOriginal': 'duterte never again.',
#       'authorDisplayName': '@sundaysbest8023',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nva7Mz8j75Z2hszYBp3_9SKnaMUcAF_MBgwWew-0I=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@sundaysbest8023',
#       'authorChannelId': {'value': 'UCT_MGciU5KydGJNegNjH19w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T20:16:59Z',
#       'updatedAt': '2024-08-27T20:16:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'grxEasVsh_TsnQaGdiea_choAvQ',
#    'id': 'Ugzy-1-OkmXc96bAkKZ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3xqehCCC_Bz6QCX8nppsk76aZMU',
#      'id': 'Ugzy-1-OkmXc96bAkKZ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Once Gibo is rightfully elected our next President in 2028 , none of this kalokohan with lazy, entitled, corruptible government agency behavior will continue. <br><br>It is high-time we have a highly intelligent,  straight-shooter, patriotic technocrat reeling in this country from the fecklessness of some seriously questionable past attempts at  “leadership”!',
#       'textOriginal': 'Once Gibo is rightfully elected our next President in 2028 , none of this kalokohan with lazy, entitled, corruptible government agency behavior will continue. \n\nIt is high-time we have a highly intelligent,  straight-shooter, patriotic technocrat reeling in this country from the fecklessness of some seriously questionable past attempts at  “leadership”!',
#       'authorDisplayName': '@pushslice',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mN6SlDGBHoohXLR99I7jHowYzzRKfxEFN8MwiNhD8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@pushslice',
#       'authorChannelId': {'value': 'UC-M9rGOPhWMphZUrCqYtx9Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T19:26:58Z',
#       'updatedAt': '2024-08-27T19:28:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9EPBR5N0Pahnmy76lW0twkW66Jw',
#    'id': 'Ugw2Un4yUfHtl9gjSH14AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'CkauD4ELWpqzS7K8PCL3DkvR0Hc',
#      'id': 'Ugw2Un4yUfHtl9gjSH14AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'magkano bayad pag escape beauru?',
#       'textOriginal': 'magkano bayad pag escape beauru?',
#       'authorDisplayName': '@CounterStrikeZer0',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mVnfLT_l3GT3Cvq_DZMcBMeo_oEZJI3UTnPvxVUwUdUIo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@CounterStrikeZer0',
#       'authorChannelId': {'value': 'UCtqRQmEVLFngPJERi0OgV0A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T19:12:55Z',
#       'updatedAt': '2024-08-27T19:12:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'n61sIB4dNuPpP_LsaVG7W0RXV9I',
#    'id': 'UgyHj5rATRDFLwzQ45t4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9g4gK7qjHDMcmKO2rsnGWvSbqLw',
#      'id': 'UgyHj5rATRDFLwzQ45t4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'She’s just another two faced Chinese.',
#       'textOriginal': 'She’s just another two faced Chinese.',
#       'authorDisplayName': '@ConwayTruckload',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lBZMyM987LabVn5552i3BbMSiiopSeo-E4nkVZPT4KNpc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ConwayTruckload',
#       'authorChannelId': {'value': 'UCWOS3UKL6IIIir8-MqcnYNA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T17:30:17Z',
#       'updatedAt': '2024-08-27T17:30:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'J2VTzB6Bm7e2C-pqPKlAR7I4CjU',
#    'id': 'UgxT7ycdlD1zG-KXb3p4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '1Cf9Mg4dcQ4vIHP8gwrxrwxsiGM',
#      'id': 'UgxT7ycdlD1zG-KXb3p4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Dapat isang tanong isang sagot un to clarify and transparency un.... Hindi ika galit? Pera ngtaong bayan..',
#       'textOriginal': 'Dapat isang tanong isang sagot un to clarify and transparency un.... Hindi ika galit? Pera ngtaong bayan..',
#       'authorDisplayName': '@user-hw1ur6rv2y',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lDSJSDjAUAtuef0JTtAFXzaAujtvgNy8NZpTO3bv855fKQsLRkeAc5pd5228DEub_8fA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-hw1ur6rv2y',
#       'authorChannelId': {'value': 'UCNCVoB5Wa9B6yQAvEajnFzg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-08-27T16:26:10Z',
#       'updatedAt': '2024-08-27T16:26:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yYSSlLwzaRX2iS1IwK6m4aThd6s',
#    'id': 'Ugxm4d9whY4O71cV5WZ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_IIHmZ-wXanLs2512Jcatb5eGwY',
#      'id': 'Ugxm4d9whY4O71cV5WZ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Alice is in dyakarta indonecia hulihin nyo na',
#       'textOriginal': 'Alice is in dyakarta indonecia hulihin nyo na',
#       'authorDisplayName': '@FilipinainGermany',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/_LKoCkKISy6hNoDUWwfTmpPlR8gFgPrayVCNMlarhSb5hswp1bVqQbfTF-OxePXGpaBRpQPtKg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@FilipinainGermany',
#       'authorChannelId': {'value': 'UC6uHQvsCtKaUAWUCO3LiLxw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T15:10:48Z',
#       'updatedAt': '2024-08-27T15:10:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_EC_ZjsNfSPFLVDZppAGSxl0UpE',
#    'id': 'UgxU7yxga6J9L5W_oWJ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'dzLiWgTwPQSRFo1s7152Uvyss-I',
#      'id': 'UgxU7yxga6J9L5W_oWJ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Marcos Ferdinand Jr. Is a wholesome character and very well spoken. He is sadly overlooked by many with political drama that paints him through past history. 😢',
#       'textOriginal': 'Marcos Ferdinand Jr. Is a wholesome character and very well spoken. He is sadly overlooked by many with political drama that paints him through past history. 😢',
#       'authorDisplayName': '@learningtobefilipino8606',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/1OXQCg-QcogOdeW3Y1vorrN--SxWGinxiS4N-Fzq_7wkplwCwFNNaP4tx5nyED3nbQv_vljfAw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@learningtobefilipino8606',
#       'authorChannelId': {'value': 'UC1KzpV_WSOh4xW8y2fxO-8w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 5,
#       'publishedAt': '2024-08-27T14:52:39Z',
#       'updatedAt': '2024-08-27T14:52:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zQy0TLinycM_FsIUOqqWWnHo0Fo',
#    'id': 'UgxyzVCaTBVqvcdM7nt4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'IaX4N2cltfVKb3cC3JKeBam2D1U',
#      'id': 'UgxyzVCaTBVqvcdM7nt4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Pagkatapos nyan Impeachment naman ang talakayin nyo.',
#       'textOriginal': 'Pagkatapos nyan Impeachment naman ang talakayin nyo.',
#       'authorDisplayName': '@VirgilioLibiran',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kreQYoMDitOiUhlQuQH74x8mvPequKq2PmlGBX4V_wyc2XSilO-PC-h-9Bd0LaJiGN4A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@VirgilioLibiran',
#       'authorChannelId': {'value': 'UCe118QK7FwCi0wL9d4JkJSA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-08-27T14:29:52Z',
#       'updatedAt': '2024-08-27T14:29:52Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '32IRyAohD-U4qgaz5tmi6g0soxY',
#    'id': 'Ugz9SRFr9TqiuVXaza54AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-jzpLFF5hpDOnvKYuUE67Lmi25A',
#      'id': 'Ugz9SRFr9TqiuVXaza54AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Pauto kayo sa deskartehayaan niyo yan hindi yan c Gou',
#       'textOriginal': 'Pauto kayo sa deskartehayaan niyo yan hindi yan c Gou',
#       'authorDisplayName': '@user-xs4vs8mz7v',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_noXk-sAWIShpLBGYJF8UBkxLqTVpEyKt6wc8RbLpI9oZ9K3fTx2m76BhURFUTEFDYu2Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-xs4vs8mz7v',
#       'authorChannelId': {'value': 'UCCBiztPUxtk24u06DgRJ6Cg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T14:23:13Z',
#       'updatedAt': '2024-08-27T14:23:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CY2YVZRVdJ_VevLznrufXkKshjk',
#    'id': 'Ugymt69X4MddRZfdp7F4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'cjJ-WZsSQsnxVS5bMafcCMCiho8',
#      'id': 'Ugymt69X4MddRZfdp7F4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Sa na ma ramdan ni Rodrigo dutuerte ngayon kung anong ginawa niya kay Leni Robredo vice president niya noon kay ganun din gagawin kay Sarah Anak niya. Weather weather la ang yan',
#       'textOriginal': 'Sa na ma ramdan ni Rodrigo dutuerte ngayon kung anong ginawa niya kay Leni Robredo vice president niya noon kay ganun din gagawin kay Sarah Anak niya. Weather weather la ang yan',
#       'authorDisplayName': '@lynnobero1386',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lue5KSYplcgLhB7BI-vNteh85cyoC5MHFM4b6o1NsFNQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@lynnobero1386',
#       'authorChannelId': {'value': 'UC_zk4eB8uhUl8wBDWixQAtA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T14:09:26Z',
#       'updatedAt': '2024-08-27T14:09:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'V44udT3PsuRPIIzkH4vwVk-Y4bc',
#    'id': 'UgxjF64cF-AKKFbKGNx4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'joxn7_h42rDfYKK9813pFE3Xxyo',
#      'id': 'UgxjF64cF-AKKFbKGNx4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Should tell to Sheila being used as Decoy/Bait, make it her curious as betrayal. Be creative and manipulate minds for those Chinese liars',
#       'textOriginal': 'Should tell to Sheila being used as Decoy/Bait, make it her curious as betrayal. Be creative and manipulate minds for those Chinese liars',
#       'authorDisplayName': '@kristicrevmobilcasualg4765',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-Rtmg1_X3OHVvMN3NcrWiaI4la86WWaOZ9nnYOBujuIVsua_OrJFnaKikehPRqgSTTntmqR7pjI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@kristicrevmobilcasualg4765',
#       'authorChannelId': {'value': 'UC5LM0QbM0P3YOKkYaM8XCsg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-08-27T13:40:06Z',
#       'updatedAt': '2024-08-27T13:40:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5qJUATjF3WwSppv0xidbpiOS0T4',
#    'id': 'UgyE4h4KEnxJE6JoskB4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ByhMSFmsftkItpryEkGRo3rtgkA',
#      'id': 'UgyE4h4KEnxJE6JoskB4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Basta Budget Gahaman yng si sara.',
#       'textOriginal': 'Basta Budget Gahaman yng si sara.',
#       'authorDisplayName': '@litosoriano2338',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mkWcXGW4tQtJ-zzuLpvMwDoCRj32Z_nsqYKKZ9xb0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@litosoriano2338',
#       'authorChannelId': {'value': 'UCLMHDkNSQoKdltquejeNMKQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T12:04:41Z',
#       'updatedAt': '2024-08-27T12:04:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VHnDSdjBAVfvowexZXv_pcfniTo',
#    'id': 'UgzTGSOI08mhVKtcMFJ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tVAPM1-x4H3mgZqHsr_OkwPvdjI',
#      'id': 'UgzTGSOI08mhVKtcMFJ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Go3x VP to explain now issue of 125 CIF pra matpos n ang question vs Cong Castro',
#       'textOriginal': 'Go3x VP to explain now issue of 125 CIF pra matpos n ang question vs Cong Castro',
#       'authorDisplayName': '@gilbertobanaga9874',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kou3dO5GhrvBQru7jrDY7-p0Ls3-FwpdfJn_A0CdgtFmBIy5ofV2XYbnym-k-Zi8t6WA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gilbertobanaga9874',
#       'authorChannelId': {'value': 'UCFGZbOzdVLwVYFX2QSZPXKw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T12:00:17Z',
#       'updatedAt': '2024-08-27T12:00:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'uIIh5BKso2r-Q9mgK-eT3w648EM',
#    'id': 'UgxKOsjrqioeaUnsky94AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ANIjkOusGcX5tpC5Vqjoj-Z3lao',
#      'id': 'UgxKOsjrqioeaUnsky94AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Ano?sabi ni Marcos BongBong si Alice marami silang sendecate ikaw at asawa pinono sa kojc wl kayong ginamit na mga armas saksakan ka ng kasinongalingan',
#       'textOriginal': 'Ano?sabi ni Marcos BongBong si Alice marami silang sendecate ikaw at asawa pinono sa kojc wl kayong ginamit na mga armas saksakan ka ng kasinongalingan',
#       'authorDisplayName': '@user-dz1bd5jr3k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mjZi_Cmr1Wv_oa6wnSfwm4w9nL11vHiHSuaMX4etjkbLSFE_XNB-51cN9MFralzuTC30ur0UJ6=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-dz1bd5jr3k',
#       'authorChannelId': {'value': 'UCNhF_Zw7qOo0HxzY-7YRM8w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T11:45:45Z',
#       'updatedAt': '2024-08-27T11:45:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'iJqKDKzeQR_WMtas0eR-hvmdBcU',
#    'id': 'UgzOFO8lFUQiLQkyONZ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4_14-7fpDZ-QCBXx5N0rTBQyI6U',
#      'id': 'UgzOFO8lFUQiLQkyONZ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Ang mga taga Senate sila sila lng naglolokohan',
#       'textOriginal': 'Ang mga taga Senate sila sila lng naglolokohan',
#       'authorDisplayName': '@user-dz1bd5jr3k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mjZi_Cmr1Wv_oa6wnSfwm4w9nL11vHiHSuaMX4etjkbLSFE_XNB-51cN9MFralzuTC30ur0UJ6=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-dz1bd5jr3k',
#       'authorChannelId': {'value': 'UCNhF_Zw7qOo0HxzY-7YRM8w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T11:39:41Z',
#       'updatedAt': '2024-08-27T11:39:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LRu7EkYzcYezF5BQmLPCJ7_ym14',
#    'id': 'UgxOQ30c-MdtrL3Yath4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U30RxFbY5XNoZy01V6LK7fDOtpQ',
#      'id': 'UgxOQ30c-MdtrL3Yath4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Bangag talaga to',
#       'textOriginal': 'Bangag talaga to',
#       'authorDisplayName': '@cvoutdoors9859',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/FNRlhC5jQ6YhCmh27HH9hDybcQr88GFUpyPzKPOVki-gucy5tbn9jOaLztsP1_UKiR0D0Lgf=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@cvoutdoors9859',
#       'authorChannelId': {'value': 'UCJkobf1IxLJJvaNEYxH9VkQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-08-27T11:23:11Z',
#       'updatedAt': '2024-08-27T11:23:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jfRkhpYL0hP0mbkuHYcWSnxhoJE',
#    'id': 'UgxiUQxWqGTlEHK3_ep4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gqXUckGWSQBcaxe8-lZw-r0Msfc',
#      'id': 'UgxiUQxWqGTlEHK3_ep4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Nasa senate tinu tutor ng abogago😂😂😂😂😂😂',
#       'textOriginal': 'Nasa senate tinu tutor ng abogago😂😂😂😂😂😂',
#       'authorDisplayName': '@gilbertvoy6422',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nuwH9VPagzcGqh-3dS6W88Hd1uHgbQ41R65eimUMo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gilbertvoy6422',
#       'authorChannelId': {'value': 'UCJAwvVJwwFNiDCTFBh2lsog'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-08-27T11:22:35Z',
#       'updatedAt': '2024-08-27T11:22:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Xu_WjQF7sRHd9VlRQx7pziioYzU',
#    'id': 'UgxslgvT2ig09_Vu0v54AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QFBJkI5Mp6noIMx26wnUS5oUu_Q',
#      'id': 'UgxslgvT2ig09_Vu0v54AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'dutae is trying to bully them out ! typical entitled davao princess !',
#       'textOriginal': 'dutae is trying to bully them out ! typical entitled davao princess !',
#       'authorDisplayName': '@genghizkhan4612',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kEWfh-0xOG7UGJl-XX6kxTNISolEnzqa7Iid5ZBIbPYY0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@genghizkhan4612',
#       'authorChannelId': {'value': 'UCj0dHqDiSUmdsuQduS3QzVg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 10,
#       'publishedAt': '2024-08-27T11:08:24Z',
#       'updatedAt': '2024-08-27T11:08:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'EFOBGXdl8dWRs5Q0j5iMxLfzbyU',
#       'id': 'UgxslgvT2ig09_Vu0v54AaABAg.A7dSpZONt2iA7emp5kjjEE',
#       'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#        'videoId': 'yfoq-0gGTLM',
#        'textDisplay': 'Princess? Ya gotta be a human being before you can be a princess.',
#        'textOriginal': 'Princess? Ya gotta be a human being before you can be a princess.',
#        'parentId': 'UgxslgvT2ig09_Vu0v54AaABAg',
#        'authorDisplayName': '@therealbronxbull8541',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/dvRH-hfbY4rE3oXuQGAfyvbFZTehOgf4NNu2tTKWf1GTJhhLl_yYSC3vI4igNz3WA7gUGHMTfw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@therealbronxbull8541',
#        'authorChannelId': {'value': 'UCf3jEXCvsBdihmuRzpLQ8qQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-08-27T23:31:05Z',
#        'updatedAt': '2024-08-27T23:31:05Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'p9FtbBvdpfx7r_Zt-IfLDJ1BKEQ',
#    'id': 'UgwQH13oUBQAbP3MFvd4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ujNFKtp7V2HNf80YPitozy3t5eM',
#      'id': 'UgwQH13oUBQAbP3MFvd4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Dont trust b.i. they are the source of leaks to alice guo',
#       'textOriginal': 'Dont trust b.i. they are the source of leaks to alice guo',
#       'authorDisplayName': '@williamzabiski7653',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mOrl-ksiMyodtHENWrT9AVPIvwUTbi_3B8L1imz_U=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@williamzabiski7653',
#       'authorChannelId': {'value': 'UCqUpPQMhLUlrnY3Ep7Jty5A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-08-27T10:59:59Z',
#       'updatedAt': '2024-08-27T10:59:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ioh0pbIBpSQq_YIfxMlSB1AhKpI',
#    'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'w9-26xE5TnlTuinotHhcHSrn7v4',
#      'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#      'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#       'videoId': 'yfoq-0gGTLM',
#       'textDisplay': 'Pres BBM is a very dignified head of the country. Very professional and very precised in giving instructions and comments. The previous leader of the country remains contributing evil command with her beloved daughter, not a positive leader of the country, never.',
#       'textOriginal': 'Pres BBM is a very dignified head of the country. Very professional and very precised in giving instructions and comments. The previous leader of the country remains contributing evil command with her beloved daughter, not a positive leader of the country, never.',
#       'authorDisplayName': '@ralphborgyyasudnaj2524',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n5uH7mFEfL3HSGS-K_JdIKbwHMg2422zz2hQh_MG_Qs10=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ralphborgyyasudnaj2524',
#       'authorChannelId': {'value': 'UCeohjGoX2EK1FlGsuVJ1SUw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 20,
#       'publishedAt': '2024-08-27T10:57:10Z',
#       'updatedAt': '2024-08-27T10:57:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 8,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'txDUIYV_nbtfeg3XrOqciMcqweY',
#       'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dRyhsr2Rf',
#       'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#        'videoId': 'yfoq-0gGTLM',
#        'textDisplay': 'The previous one wants to make philippines a province of china 😂',
#        'textOriginal': 'The previous one wants to make philippines a province of china 😂',
#        'parentId': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#        'authorDisplayName': '@williamzabiski7653',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mOrl-ksiMyodtHENWrT9AVPIvwUTbi_3B8L1imz_U=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@williamzabiski7653',
#        'authorChannelId': {'value': 'UCqUpPQMhLUlrnY3Ep7Jty5A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2024-08-27T11:00:55Z',
#        'updatedAt': '2024-08-27T11:00:55Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Ec-sHWoKvtHX524PUzQAQkBPbIk',
#       'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dSXN3ixKS',
#       'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#        'videoId': 'yfoq-0gGTLM',
#        'textDisplay': 'LBM ONG TRAYDOR',
#        'textOriginal': 'LBM ONG TRAYDOR',
#        'parentId': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#        'authorDisplayName': '@Romy5356',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ktgf3psRkAgKqgtBrHqhFCpTwn8CtlBGMPzkRqQ28gVAm_OArHXAgXv_ztPUnBWg1sIA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@Romy5356',
#        'authorChannelId': {'value': 'UCm0AF3McorO6qMsfRZb3lwg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-08-27T11:05:47Z',
#        'updatedAt': '2024-08-27T11:05:47Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '5rpM3dyLGVn4vwabAXX8jBmL49k',
#       'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dUIMBsnFa',
#       'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#        'videoId': 'yfoq-0gGTLM',
#        'textDisplay': 'Very singhot',
#        'textOriginal': 'Very singhot',
#        'parentId': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#        'authorDisplayName': '@cvoutdoors9859',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/FNRlhC5jQ6YhCmh27HH9hDybcQr88GFUpyPzKPOVki-gucy5tbn9jOaLztsP1_UKiR0D0Lgf=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@cvoutdoors9859',
#        'authorChannelId': {'value': 'UCJkobf1IxLJJvaNEYxH9VkQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-08-27T11:21:13Z',
#        'updatedAt': '2024-08-27T11:21:13Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'oWKJmHIoL8ywfYxwUz57gdMbacg',
#       'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dUhI_shHq',
#       'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#        'videoId': 'yfoq-0gGTLM',
#        'textDisplay': 'Ul*l dignified. Pinapakyuhan nga si Bong Daza sa picture nung nag aadik sila. Hindi ka ba updated? 😂 nilantad na kung sino kumanta sa kanila. Palit ulo',
#        'textOriginal': 'Ul*l dignified. Pinapakyuhan nga si Bong Daza sa picture nung nag aadik sila. Hindi ka ba updated? 😂 nilantad na kung sino kumanta sa kanila. Palit ulo',
#        'parentId': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#        'authorDisplayName': '@sto.8981',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/EHVVhvu8zbtlau5BFrO6Wld0McsNzchT119R1HV4EETWrgZHBxFTB_lsFJI35iDLEVYpkocA7A=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@sto.8981',
#        'authorChannelId': {'value': 'UC5u3ch5W2eRNAC1vPxN7z1g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-08-27T11:24:46Z',
#        'updatedAt': '2024-08-27T11:24:46Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Zlem7jJF7Qx8VYHkqh-o2ekJ6Bw',
#       'id': 'UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dg8wVOyF-',
#       'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#        'videoId': 'yfoq-0gGTLM',
#        'textDisplay': 'That vp is rude, entitled and arrogant like her father they&#39;re used to spending money without being questioned and acting like kings and queens in Davao that&#39;s why she&#39;s so piqued she has no accountability and very shameless!!!',
#        'textOriginal': "That vp is rude, entitled and arrogant like her father they're used to spending money without being questioned and acting like kings and queens in Davao that's why she's so piqued she has no accountability and very shameless!!!",
#        'parentId': 'UgwBBzeGtqWna6y4KUJ4AaABAg',
#        'authorDisplayName': '@cutekitty3067',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nG476pzxlYUSLb7bJySPR-uQPcWUi47RfAyFM5EJVZNdE=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@cutekitty3067',
#        'authorChannelId': {'value': 'UCBdY8O_03nF8A9JvHwEUm3A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2024-08-27T13:13:32Z',
#        'updatedAt': '2024-08-27T13:13:32Z'}}]}}]}

# %% [markdown]
# We can see that the contents are quite long, but if we take the time to analyze it, we'll realize it's really just a nested dictionary with the following keys: `kind`, `etag`, `nextPageToken`, `pageInfo`, and `items`.
#
# The values in `pageInfo` tell us how many results are included in this set--in this case, 50 comments and their corresponding replies. The 50 comments are contained as dictionaries within the `items` key.
#
# To confirm, let's check the length of the `items`.

# %%
len(video_response['items'])
# Out:
# 25

# %% [markdown]
# ## Inspecting a single YouTube comment

# %% [markdown]
# Now, let's try and see what each item in the response looks like. Let's examine the 1st item in the list.

# %%
video_response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'KwQ8MckUnNNTj0heexX_ywyh6sc',
#  'id': 'UgzmI6rrrSbY2I4XZTd4AaABAg',
#  'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#   'videoId': 'yfoq-0gGTLM',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'BNE0HFymQ4Vds3IsOY1HDEtwem8',
#    'id': 'UgzmI6rrrSbY2I4XZTd4AaABAg',
#    'snippet': {'channelId': 'UCvRAX-ujvZ0eTMLGG2vki9w',
#     'videoId': 'yfoq-0gGTLM',
#     'textDisplay': 'Ang kapalpakan ng marcos admin lumaganap na ulit ang droga kay duterte oarin isinisisi, may god i hate cocaine.',
#     'textOriginal': 'Ang kapalpakan ng marcos admin lumaganap na ulit ang droga kay duterte oarin isinisisi, may god i hate cocaine.',
#     'authorDisplayName': '@2littlebee1',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ndI6ZouWopQgS2uB15Ofp0k1WFDSPMH9F5_xSaGgz16sk=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@2littlebee1',
#     'authorChannelId': {'value': 'UCKi4zLPRj1ChJmYfyIHKvkA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-08-28T11:55:23Z',
#     'updatedAt': '2024-08-28T11:55:23Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %% [markdown]
# We can extract the following
# - textDisplay
# - id
# - publishedAt
# - textOriginal
#
# Then add additional features
# - likeCount
# - repliedParentId

# %%
# For the original comment
print(
  f'https://www.youtube.com/watch?v={video_id}&lc={video_response["items"][0]["snippet"]["topLevelComment"]["id"]}'
)
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['likeCount'])
# No repliedParentId
# Out:
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgzmI6rrrSbY2I4XZTd4AaABAg
# Ang kapalpakan ng marcos admin lumaganap na ulit ang droga kay duterte oarin isinisisi, may god i hate cocaine.
# 2024-08-28T11:55:23Z
# Ang kapalpakan ng marcos admin lumaganap na ulit ang droga kay duterte oarin isinisisi, may god i hate cocaine.
# 0

# %% [markdown]
# ## Extracting replies from comment

# %% [markdown]
# If `totalReplyCount` is greater than 0, we can extract the replies to the comment.
# In the `video_response` object, we can see that the replies are nested within the `comments` key. HOWEVER, this method does not include all replies.
#
# As such, we have to use the `comments.list` method to get all replies to a comment.
# Refer to [CommentsList](https://developers.google.com/youtube/v3/docs/comments/list) document for more information.

# %%
video_response['items'][-1]['snippet']['totalReplyCount']
# Out:
# 8

# %%
len(
  video_response['items'][-1]['replies']['comments']
)
# Out:
# 5

# %% [markdown]
# Using a similar process, we can also extract the one reply to this comment. We know there's three replies because of the value of the `totalReplyCount` key.

# %%
comment_number = -1
total_reply_count = video_response['items'][comment_number]['snippet']['totalReplyCount']

if total_reply_count > 0:
  parent_id = video_response['items'][comment_number]['snippet']['topLevelComment']['id']

  replies = youtube.comments().list(
    part='snippet', parentId=parent_id, maxResults=50
  ).execute()

  for reply in replies['items']:
    print(
      f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}"
    )
    print(reply['snippet']['textDisplay'])
    print(reply['snippet']['publishedAt'])
    print(reply['snippet']['textOriginal'])
    print(reply['snippet']['likeCount'])
    print(reply['snippet']['parentId'])
    print()
# Out:
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dRyhsr2Rf
# The previous one wants to make philippines a province of china 😂
# 2024-08-27T11:00:55Z
# The previous one wants to make philippines a province of china 😂
# 4
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dSXN3ixKS
# LBM ONG TRAYDOR
# 2024-08-27T11:05:47Z
# LBM ONG TRAYDOR
# 0
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dUIMBsnFa
# Very singhot
# 2024-08-27T11:21:13Z
# Very singhot
# 0
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dUhI_shHq
# Ul*l dignified. Pinapakyuhan nga si Bong Daza sa picture nung nag aadik sila. Hindi ka ba updated? 😂 nilantad na kung sino kumanta sa kanila. Palit ulo
# 2024-08-27T11:24:46Z
# Ul*l dignified. Pinapakyuhan nga si Bong Daza sa picture nung nag aadik sila. Hindi ka ba updated? 😂 nilantad na kung sino kumanta sa kanila. Palit ulo
# 0
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dg8wVOyF-
# That vp is rude, entitled and arrogant like her father they&#39;re used to spending money without being questioned and acting like kings and queens in Davao that&#39;s why she&#39;s so piqued she has no accountability and very shameless!!!
# 2024-08-27T13:13:32Z
# That vp is rude, entitled and arrogant like her father they're used to spending money without being questioned and acting like kings and queens in Davao that's why she's so piqued she has no accountability and very shameless!!!
# 2
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dnOuM6uCk
# What country is this? Very interesting.
# 2024-08-27T14:16:52Z
# What country is this? Very interesting.
# 0
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7dtzVfXlWP
# @@cvoutdoors9859palamunin
# 2024-08-27T15:14:26Z
# @@cvoutdoors9859palamunin
# 0
# UgwBBzeGtqWna6y4KUJ4AaABAg
#
# https://www.youtube.com/watch?v=yfoq-0gGTLM&lc=UgwBBzeGtqWna6y4KUJ4AaABAg.A7dRYCHsjCfA7eC-1D-RZc
# That’s true
# 2024-08-27T18:00:32Z
# That’s true
# 0
# UgwBBzeGtqWna6y4KUJ4AaABAg

# %% [markdown]
# ## Automating the extraction

# %% [markdown]
# Now that we know how to extract individual comments from YouTube videos, we need to figure out how we can automate this process so that we can build a corpus of comments without manually getting comments and replies one by one.
#
# To do this, we rely on the following:
# 1.   the consistency of the nested dictionary results structure of the YouTube API
# 2.   Python loops
# 3.   page tokens
#
# Let's work on the first two.

# %% [markdown]
# First, we create a list where we will store all scraped data.

# %%
comments = []

# %% [markdown]
# Then, we use loops to iterate through the contents of `video_response`.

# %%
# iterate through items
for item in video_response['items']:

  # extract comment from each item
  comment = item['snippet']['topLevelComment']['snippet']

  # append comment to list of comments
  comments.append([
    comment['textDisplay'],
    f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
    comment['publishedAt'],
    comment['textOriginal'],
    comment['likeCount'],
    np.nan
  ])

  # count number of replies
  total_reply_count = item['snippet']['totalReplyCount']

  # if there is at least one reply
  if total_reply_count > 0:
    parent_id = item["snippet"]["topLevelComment"]["id"]

    replies = youtube.comments().list(
      part='snippet', parentId=parent_id, maxResults=50
    ).execute()

    # iterate through the replies
    for reply in replies['items']:
      # extract text from each reply
      # append reply to list of comments
      replyBody = reply['snippet']
      comments.append([
        replyBody['textDisplay'],
        f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
        replyBody['publishedAt'],
        replyBody['textOriginal'],
        replyBody['likeCount'],
        replyBody['parentId']
      ])

# %%
youtube_corpus = pd.DataFrame(
  comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id'])
youtube_corpus
# Out:
#                                                 title  \
# 0   Ang kapalpakan ng marcos admin lumaganap na ul...
# 1   Only this type of human race can go anywhere i...
# 2              Mga duterte puro angas wala naman gawa
# 3   Now that you know she is in Jakarta what is th...
# 4                                       Huliin na po!
# 5                                duterte never again.
# 6   Once Gibo is rightfully elected our next Presi...
# 7                    magkano bayad pag escape beauru?
# 8               She’s just another two faced Chinese.
# 9   Dapat isang tanong isang sagot un to clarify a...
# 10      Alice is in dyakarta indonecia hulihin nyo na
# 11  Marcos Ferdinand Jr. Is a wholesome character ...
# 12  Pagkatapos nyan Impeachment naman ang talakayi...
# 13  Pauto kayo sa deskartehayaan niyo yan hindi ya...
# 14  Sa na ma ramdan ni Rodrigo dutuerte ngayon kun...
# 15  Should tell to Sheila being used as Decoy/Bait...
# 16                  Basta Budget Gahaman yng si sara.
# 17  Go3x VP to explain now issue of 125 CIF pra ma...
# 18  Ano?sabi ni Marcos BongBong si Alice marami si...
# 19     Ang mga taga Senate sila sila lng naglolokohan
# 20                                   Bangag talaga to
# 21            Nasa senate tinu tutor ng abogago😂😂😂😂😂😂
# 22  dutae is trying to bully them out ! typical en...
# 23  Princess? Ya gotta be a human being before you...
# 24  Dont trust b.i. they are the source of leaks t...
# 25  Pres BBM is a very dignified head of the count...
# 26  The previous one wants to make philippines a p...
# 27                                    LBM ONG TRAYDOR
# 28                                       Very singhot
# 29  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...
# 30  That vp is rude, entitled and arrogant like he...
# 31            What country is this? Very interesting.
# 32                          @@cvoutdoors9859palamunin
# 33                                        That’s true
#
#                                                  link        date_published  \
# 0   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-28T11:55:23Z
# 1   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T23:12:34Z
# 2   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T22:36:52Z
# 3   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T21:59:23Z
# 4   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T21:05:23Z
# 5   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T20:16:59Z
# 6   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T19:26:58Z
# 7   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T19:12:55Z
# 8   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T17:30:17Z
# 9   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T16:26:10Z
# 10  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T15:10:48Z
# 11  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:52:39Z
# 12  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:29:52Z
# 13  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:23:13Z
# 14  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:09:26Z
# 15  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T13:40:06Z
# 16  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T12:04:41Z
# 17  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T12:00:17Z
# 18  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:45:45Z
# 19  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:39:41Z
# 20  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:23:11Z
# 21  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:22:35Z
# 22  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:08:24Z
# 23  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T23:31:05Z
# 24  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T10:59:59Z
# 25  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T10:57:10Z
# 26  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:00:55Z
# 27  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:05:47Z
# 28  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:21:13Z
# 29  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:24:46Z
# 30  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T13:13:32Z
# 31  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:16:52Z
# 32  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T15:14:26Z
# 33  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T18:00:32Z
#
#                                                  text  like_count  \
# 0   Ang kapalpakan ng marcos admin lumaganap na ul...           0
# 1   Only this type of human race can go anywhere i...           0
# 2              Mga duterte puro angas wala naman gawa           0
# 3   Now that you know she is in Jakarta what is th...           0
# 4                                       Huliin na po!           0
# 5                                duterte never again.           0
# 6   Once Gibo is rightfully elected our next Presi...           0
# 7                    magkano bayad pag escape beauru?           0
# 8               She’s just another two faced Chinese.           0
# 9   Dapat isang tanong isang sagot un to clarify a...           1
# 10      Alice is in dyakarta indonecia hulihin nyo na           0
# 11  Marcos Ferdinand Jr. Is a wholesome character ...           5
# 12  Pagkatapos nyan Impeachment naman ang talakayi...           1
# 13  Pauto kayo sa deskartehayaan niyo yan hindi ya...           0
# 14  Sa na ma ramdan ni Rodrigo dutuerte ngayon kun...           0
# 15  Should tell to Sheila being used as Decoy/Bait...           1
# 16                  Basta Budget Gahaman yng si sara.           0
# 17  Go3x VP to explain now issue of 125 CIF pra ma...           0
# 18  Ano?sabi ni Marcos BongBong si Alice marami si...           0
# 19     Ang mga taga Senate sila sila lng naglolokohan           0
# 20                                   Bangag talaga to           0
# 21            Nasa senate tinu tutor ng abogago😂😂😂😂😂😂           2
# 22  dutae is trying to bully them out ! typical en...          10
# 23  Princess? Ya gotta be a human being before you...           0
# 24  Dont trust b.i. they are the source of leaks t...           1
# 25  Pres BBM is a very dignified head of the count...          20
# 26  The previous one wants to make philippines a p...           4
# 27                                    LBM ONG TRAYDOR           0
# 28                                       Very singhot           0
# 29  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...           0
# 30  That vp is rude, entitled and arrogant like he...           2
# 31            What country is this? Very interesting.           0
# 32                          @@cvoutdoors9859palamunin           0
# 33                                        That’s true           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23  UgxslgvT2ig09_Vu0v54AaABAg
# 24                         NaN
# 25                         NaN
# 26  UgwBBzeGtqWna6y4KUJ4AaABAg
# 27  UgwBBzeGtqWna6y4KUJ4AaABAg
# 28  UgwBBzeGtqWna6y4KUJ4AaABAg
# 29  UgwBBzeGtqWna6y4KUJ4AaABAg
# 30  UgwBBzeGtqWna6y4KUJ4AaABAg
# 31  UgwBBzeGtqWna6y4KUJ4AaABAg
# 32  UgwBBzeGtqWna6y4KUJ4AaABAg
# 33  UgwBBzeGtqWna6y4KUJ4AaABAg

# %% [markdown]
# ## Handling next page with page tokens

# %% [markdown]
# Let's take another example with more comments.
#
# We'll have a list of 50 or so comments from the video.
#
# However, if we check the video's comments section, we'll see that there are 128 comments in the video.
#
# So how can we extract more comments? That's where `pageToken` comes in.

# %%
video_id = '0v1XHgWyIvU'
video_response = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time'
).execute()

# iterate through items
for item in video_response['items']:

  # extract comment from each item
  comment = item['snippet']['topLevelComment']['snippet']

  # append comment to list of comments
  comments.append([
    comment['textDisplay'],
    f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
    comment['publishedAt'],
    comment['textOriginal'],
    comment['likeCount'],
    np.nan
  ])

  # count number of replies
  total_reply_count = item['snippet']['totalReplyCount']

  # if there is at least one reply
  if total_reply_count > 0:
    parent_id = item["snippet"]["topLevelComment"]["id"]

    replies = youtube.comments().list(
      part='snippet', parentId=parent_id, maxResults=50
    ).execute()

    # iterate through the replies
    for reply in replies['items']:
      # extract text from each reply
      # append reply to list of comments
      replyBody = reply['snippet']
      comments.append([
        replyBody['textDisplay'],
        f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
        replyBody['publishedAt'],
        replyBody['textOriginal'],
        replyBody['likeCount'],
        replyBody['parentId']
      ])

youtube_corpus = pd.DataFrame(
  comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id'])
youtube_corpus
# Out:
#                                                 title  \
# 0   Ang kapalpakan ng marcos admin lumaganap na ul...
# 1   Only this type of human race can go anywhere i...
# 2              Mga duterte puro angas wala naman gawa
# 3   Now that you know she is in Jakarta what is th...
# 4                                       Huliin na po!
# ..                                                ...
# 80   PI tlaga sa pilipinas! ginag*g0 na lang mga tao.
# 81  SERVICE FROM THE INTERPOOL IS HIGHLY NEEDED❤😮 ...
# 82                Interfool 🤣 . Interpol po yata yon…
# 83  yung attorney nila patawan nyo ng administrati...
# 84  Puro nalang kuwento ang resulta sa pag iimbist...
#
#                                                  link        date_published  \
# 0   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-28T11:55:23Z
# 1   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T23:12:34Z
# 2   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T22:36:52Z
# 3   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T21:59:23Z
# 4   https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T21:05:23Z
# ..                                                ...                   ...
# 80  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T14:22:49Z
# 81  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T14:22:11Z
# 82  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-23T14:17:24Z
# 83  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T14:18:47Z
# 84  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T14:16:12Z
#
#                                                  text  like_count  \
# 0   Ang kapalpakan ng marcos admin lumaganap na ul...           0
# 1   Only this type of human race can go anywhere i...           0
# 2              Mga duterte puro angas wala naman gawa           0
# 3   Now that you know she is in Jakarta what is th...           0
# 4                                       Huliin na po!           0
# ..                                                ...         ...
# 80   PI tlaga sa pilipinas! ginag*g0 na lang mga tao.           0
# 81  SERVICE FROM THE INTERPOOL IS HIGHLY NEEDED❤😮 ...           1
# 82                Interfool 🤣 . Interpol po yata yon…           0
# 83  yung attorney nila patawan nyo ng administrati...           0
# 84  Puro nalang kuwento ang resulta sa pag iimbist...           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 80                         NaN
# 81                         NaN
# 82  Ugz3RrSepytB8qik2WV4AaABAg
# 83                         NaN
# 84                         NaN
#
# [85 rows x 6 columns]

# %% [markdown]
# If we return to the contents of `video_response`, we'll see that one of its keys is the `nextPageToken` key. This key is like an ID that distinguishes the pages within a set of search results--in this case, the comments section of the video.
#
# If we add a `pageToken` argument to our `youtube.commentThreads().list()` method, you'll see that we will get different results from the previous one.

# %%
# Check whether video_response has `nextPageToken`
video_response['nextPageToken']
# Out:
# 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWtnR0FBU0JRaWRJQmdCR0FBaURnb01DS3luamJZR0VMQ1F2SjBC'

# %%
# Make the same request but with the `nextPageToken`
video_response_2 = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time',
  pageToken=video_response['nextPageToken']
).execute()

# %%
video_response_2['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']
# Out:
# 'as long as you pay, gov do everything for you'

# %% [markdown]
# Let's now incorporate `pageToken` into our loop.

# %%
# how many comments do we want
no_comments = 500

# re-initialize list of YouTube comments
comments = []
youtube_corpus = None

video_id = '0v1XHgWyIvU'  # more comments
# video_id = 'yfoq-0gGTLM' # fewer comments

# get first page of the comments
video_response = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time', moderationStatus='published'
).execute()

while len(comments) < no_comments:
  # iterate through items
  for item in video_response['items']:
    ##### Parent Comments #####
    # extract comment from each item
    comment = item['snippet']['topLevelComment']['snippet']

    # append comment to list of comments
    comments.append([
      comment['textDisplay'],
      f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
      comment['publishedAt'],
      comment['textOriginal'],
      comment['likeCount'],
      np.nan
    ])

    ##### Reply Comments #####
    # count number of replies
    total_reply_count = item['snippet']['totalReplyCount']

    # if there is at least one reply
    if total_reply_count > 0:
      parent_id = item["snippet"]["topLevelComment"]["id"]

      replies = youtube.comments().list(
        part='snippet',
        parentId=parent_id
      ).execute()

      # iterate through the replies
      for reply in replies['items']:
        # extract text from each reply
        # append reply to list of comments
        replyBody = reply['snippet']
        comments.append([
          replyBody['textDisplay'],
          f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
          replyBody['publishedAt'],
          replyBody['textOriginal'],
          replyBody['likeCount'],
          replyBody['parentId']
        ])

  ##### Next Page #####
  # print number of comments
  print(str(len(comments)) + ' comments in list')

  # if there is a next page to the comment result
  if 'nextPageToken' in video_response:
    # notify that next page has been found
    print('Next comment page found. Now extracting data. \n')

    # get the next page
    video_response = youtube.commentThreads().list(
      videoId=video_id, part='snippet,replies', maxResults=50,
      order='time', pageToken=video_response['nextPageToken'],
      moderationStatus='published'
    ).execute()
  else:
    # notify that no more pages are left
    print('No more comment pages left.')
    break
# Out:
# 51 comments in list
# Next comment page found. Now extracting data.
#
# 102 comments in list
# Next comment page found. Now extracting data.
#
# 128 comments in list
# No more comment pages left.

# %%
youtube_corpus = pd.DataFrame(
  comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id'])
youtube_corpus
# Out:
#                                                  title  \
# 0    Escape of guo is a reflection of country&#39;s...
# 1    BAKIT masama bang magsinungaling ? Sino bang t...
# 2                  Ano ka ngayon Honti Virus Nga Nga ?
# 3    NO TO DUTERTE AND CHINA. ARREST GUO LAWYER STE...
# 4    Grabe nakalagpas sa immigration, ano yan hindi...
# ..                                                 ...
# 123             Magkano kaya binayad oara maka eskapo?
# 124                                 Nagtatago lang yan
# 125  Iba talaga pag may Pera. Lahat ma bibili. Hay ...
# 126                                    Bakit nakalabas
# 127           Pilipinos are FOR SALE !!<br>Alam mo yan
#
#                                                   link        date_published  \
# 0    https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-27T10:40:10Z
# 1    https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-26T02:25:48Z
# 2    https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-26T02:19:50Z
# 3    https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-22T15:18:38Z
# 4    https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-22T07:58:58Z
# ..                                                 ...                   ...
# 123  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-20T11:02:17Z
# 124  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T12:15:42Z
# 125  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T12:14:12Z
# 126  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T12:12:46Z
# 127  https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-19T12:44:08Z
#
#                                                   text  like_count  \
# 0    Escape of guo is a reflection of country's  st...           0
# 1    BAKIT masama bang magsinungaling ? Sino bang t...           0
# 2                  Ano ka ngayon Honti Virus Nga Nga ?           0
# 3    NO TO DUTERTE AND CHINA. ARREST GUO LAWYER STE...           0
# 4    Grabe nakalagpas sa immigration, ano yan hindi...           0
# ..                                                 ...         ...
# 123             Magkano kaya binayad oara maka eskapo?           0
# 124                                 Nagtatago lang yan           1
# 125  Iba talaga pag may Pera. Lahat ma bibili. Hay ...           8
# 126                                    Bakit nakalabas           2
# 127             Pilipinos are FOR SALE !!\nAlam mo yan           0
#
#                 reply_parent_id
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 123  UgzidE_cOM1z3f7pnCF4AaABAg
# 124                         NaN
# 125                         NaN
# 126                         NaN
# 127  UgzWDcMGlQwTh6ULlKJ4AaABAg
#
# [128 rows x 6 columns]

# %% [markdown]
# ## Function `extract_youtube_comments`

# %% [markdown]
# Now, we can define a function that extracts a certain number of comments for a particular video and returns a list of these comments.

# %%
def extract_youtube_comments(video_id, no_comments):
  """
  Extracts comments from a YouTube video.

  Args:
    video_id (str): The ID of the YouTube video.
    no_comments (int): The number of comments to extract.

  Returns:
    pandas.DataFrame: A DataFrame containing the extracted comments with the following columns:
      - title (str): The display text of the comment.
      - link (str): The URL of the comment.
      - date_published (str): The date and time when the comment was published.
      - text (str): The original text of the comment.
      - like_count (int): The number of likes the comment has received.
      - reply_parent_id (float): The ID of the parent comment if the comment is a reply, otherwise NaN.
  """
  # re-initialize list of YouTube comments
  comments = []

  # get first page of the comments
  video_response = youtube.commentThreads().list(
    videoId=video_id, part='snippet,replies', maxResults=50,
    order='time', moderationStatus='published'
  ).execute()

  while len(comments) < no_comments:
    # iterate through items
    for item in video_response['items']:
      ##### Parent Comments #####
      # extract comment from each item
      comment = item['snippet']['topLevelComment']['snippet']

      # append comment to list of comments
      comments.append([
        comment['textDisplay'],
        f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
        comment['publishedAt'],
        comment['textOriginal'],
        comment['likeCount'],
        np.nan
      ])

      ##### Reply Comments #####
      # count number of replies
      total_reply_count = item['snippet']['totalReplyCount']

      # if there is at least one reply
      if total_reply_count > 0:
        parent_id = item["snippet"]["topLevelComment"]["id"]

        replies = youtube.comments().list(
          part='snippet',
          parentId=parent_id
        ).execute()

        # iterate through the replies
        for reply in replies['items']:
          # extract text from each reply
          # append reply to list of comments
          replyBody = reply['snippet']
          comments.append([
            replyBody['textDisplay'],
            f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
            replyBody['publishedAt'],
            replyBody['textOriginal'],
            replyBody['likeCount'],
            replyBody['parentId']
          ])

    ##### Next Page #####
    # print number of comments
    print(str(len(comments)) + ' comments in list')

    # if there is a next page to the comment result
    if 'nextPageToken' in video_response:
      # notify that next page has been found
      print('Next comment page found. Now extracting data. \n')

      # get the next page
      video_response = youtube.commentThreads().list(
        videoId=video_id, part='snippet,replies', maxResults=50,
        order='time', pageToken=video_response['nextPageToken'],
        moderationStatus='published'
      ).execute()
    else:
      # notify that no more pages are left
      print('No more comment pages left.\n')
      break

  return pd.DataFrame(
    comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id']
  )

# %%
video_links = [
  '0v1XHgWyIvU',  # more comments
  'yfoq-0gGTLM'  # fewer comments
]

aliceguo_youtube_corpus = None

for video_link in video_links:
  print(f'Extracting comments from video: {video_link}')
  if aliceguo_youtube_corpus is None:
    aliceguo_youtube_corpus = extract_youtube_comments(video_link, 750)
  else:
    aliceguo_youtube_corpus = pd.concat([
      aliceguo_youtube_corpus, extract_youtube_comments(video_link, 750)
    ])

aliceguo_youtube_corpus
# Out:
# Extracting comments from video: 0v1XHgWyIvU
# 51 comments in list
# Next comment page found. Now extracting data.
#
# 102 comments in list
# Next comment page found. Now extracting data.
#
# 128 comments in list
# No more comment pages left.
#
# Extracting comments from video: yfoq-0gGTLM
# 34 comments in list
# No more comment pages left.
#                                                 title  \
# 0   Escape of guo is a reflection of country&#39;s...
# 1   BAKIT masama bang magsinungaling ? Sino bang t...
# 2                 Ano ka ngayon Honti Virus Nga Nga ?
# 3   NO TO DUTERTE AND CHINA. ARREST GUO LAWYER STE...
# 4   Grabe nakalagpas sa immigration, ano yan hindi...
# ..                                                ...
# 29  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...
# 30  That vp is rude, entitled and arrogant like he...
# 31            What country is this? Very interesting.
# 32                          @@cvoutdoors9859palamunin
# 33                                        That’s true
#
#                                                  link        date_published  \
# 0   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-27T10:40:10Z
# 1   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-26T02:25:48Z
# 2   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-26T02:19:50Z
# 3   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-22T15:18:38Z
# 4   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-22T07:58:58Z
# ..                                                ...                   ...
# 29  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:24:46Z
# 30  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T13:13:32Z
# 31  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:16:52Z
# 32  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T15:14:26Z
# 33  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T18:00:32Z
#
#                                                  text  like_count  \
# 0   Escape of guo is a reflection of country's  st...           0
# 1   BAKIT masama bang magsinungaling ? Sino bang t...           0
# 2                 Ano ka ngayon Honti Virus Nga Nga ?           0
# 3   NO TO DUTERTE AND CHINA. ARREST GUO LAWYER STE...           0
# 4   Grabe nakalagpas sa immigration, ano yan hindi...           0
# ..                                                ...         ...
# 29  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...           0
# 30  That vp is rude, entitled and arrogant like he...           2
# 31            What country is this? Very interesting.           0
# 32                          @@cvoutdoors9859palamunin           0
# 33                                        That’s true           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 29  UgwBBzeGtqWna6y4KUJ4AaABAg
# 30  UgwBBzeGtqWna6y4KUJ4AaABAg
# 31  UgwBBzeGtqWna6y4KUJ4AaABAg
# 32  UgwBBzeGtqWna6y4KUJ4AaABAg
# 33  UgwBBzeGtqWna6y4KUJ4AaABAg
#
# [162 rows x 6 columns]

# %%
aliceguo_youtube_corpus
# Out:
#                                                 title  \
# 0   Escape of guo is a reflection of country&#39;s...
# 1   BAKIT masama bang magsinungaling ? Sino bang t...
# 2                 Ano ka ngayon Honti Virus Nga Nga ?
# 3   NO TO DUTERTE AND CHINA. ARREST GUO LAWYER STE...
# 4   Grabe nakalagpas sa immigration, ano yan hindi...
# ..                                                ...
# 29  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...
# 30  That vp is rude, entitled and arrogant like he...
# 31            What country is this? Very interesting.
# 32                          @@cvoutdoors9859palamunin
# 33                                        That’s true
#
#                                                  link        date_published  \
# 0   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-27T10:40:10Z
# 1   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-26T02:25:48Z
# 2   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-26T02:19:50Z
# 3   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-22T15:18:38Z
# 4   https://www.youtube.com/watch?v=0v1XHgWyIvU&lc...  2024-08-22T07:58:58Z
# ..                                                ...                   ...
# 29  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:24:46Z
# 30  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T13:13:32Z
# 31  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:16:52Z
# 32  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T15:14:26Z
# 33  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T18:00:32Z
#
#                                                  text  like_count  \
# 0   Escape of guo is a reflection of country's  st...           0
# 1   BAKIT masama bang magsinungaling ? Sino bang t...           0
# 2                 Ano ka ngayon Honti Virus Nga Nga ?           0
# 3   NO TO DUTERTE AND CHINA. ARREST GUO LAWYER STE...           0
# 4   Grabe nakalagpas sa immigration, ano yan hindi...           0
# ..                                                ...         ...
# 29  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...           0
# 30  That vp is rude, entitled and arrogant like he...           2
# 31            What country is this? Very interesting.           0
# 32                          @@cvoutdoors9859palamunin           0
# 33                                        That’s true           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 29  UgwBBzeGtqWna6y4KUJ4AaABAg
# 30  UgwBBzeGtqWna6y4KUJ4AaABAg
# 31  UgwBBzeGtqWna6y4KUJ4AaABAg
# 32  UgwBBzeGtqWna6y4KUJ4AaABAg
# 33  UgwBBzeGtqWna6y4KUJ4AaABAg
#
# [162 rows x 6 columns]

# %% [markdown]
# We can now save these comments to a dataframe and Excel file.

# %%
try:
  # Google Colab
  from google.colab import drive
  drive.mount('/content/drive')

  file_name = '/content/drive/MyDrive/aliceguo_youtube.xlsx'
except:
  # VS Code / Local machine
  file_name = 'aliceguo_youtube.xlsx'

aliceguo_youtube_corpus.to_excel(file_name)
print(f'File saved to {file_name}')
# Out:
# File saved to aliceguo_youtube.xlsx

# %% [markdown]
# What we've done so far is extract comments for **one** video. If you want to extract comments for multiple videos, you'll have to use the `channel`, `search`, or `playlist` resource objects of the YouTube API. You can study these more through the documentation.
#
# However, note that each account has an allocation of 10,000 units per day. Each call that uses the API costs a certain number of units, and if you reach 10,000, you won't be able to properly use the API (and possibly YouTube) until the next day.

# %% [markdown]
# Other APIs you might be interested in exploring:
# *   Genius API for extracting song lyrics (https://docs.genius.com/)
# *   Python Reddit API Wrapper (PRAW) for extracting Reddit posts (https://praw.readthedocs.io/en/stable/)
# *   Tweepy for extracting tweets (but Elon kinda ruined it now) (https://www.tweepy.org/)

# %% [markdown]
# # Method 3: Facepager

# %% [markdown]
# Facepager is an application made for automating data extraction (esp. for Facebook). Follow the installation instructions in this page: https://github.com/strohne/Facepager

# %% [markdown]
# To learn more about how to use Facepager, navigate through its wiki page: https://github.com/strohne/Facepager/wiki/Getting-Started
